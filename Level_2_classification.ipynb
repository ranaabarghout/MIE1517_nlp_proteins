# %% [markdown]
# <br>
#
# ## Imports

# %%
import time
import pickle
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torch.optim import Adam

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_curve, auc, classification_report

# %% [markdown]
# <br>
#
# Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <br>
#
# ## Define constants

# %%
TEST_SIZE = .2
EVAL_SIZE = .1
RANDOM_SEED = 30
WHICH_TARGET = 'Level_2'

# %% [markdown]
# <br>
#
# ## Define classes

# %%
class seqembData(Dataset):
    def __init__(self, inputs, labels):
        for input in inputs:
            assert input.shape[0] == len(labels)
        
        self.n = len(labels)
        self.labels = torch.as_tensor(labels)
        self.inputs = [torch.as_tensor(input).float() for input in inputs]

    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        return [input[idx] for input in self.inputs], self.labels[idx]

# %%
class ecnumClassifier(nn.Module):
    def __init__(self, input_sizes, num_classes, hidden_size = 256, linear_sizes = [64, 64], drop_prob = .2):
        super().__init__()

        # Input processing layers
        proc_layers = []
        for size in input_sizes:
            proc_layer = nn.Sequential(
                nn.Dropout(p = drop_prob),
                nn.Linear(size, hidden_size),
                nn.ReLU(),
                nn.BatchNorm1d(hidden_size)
            )
            proc_layers.append(proc_layer)
        self.proc_layers = nn.ModuleList(proc_layers)

        # Linear layers
        input_size = hidden_size * len(input_sizes)
        linear_layers = []
        for output_size in linear_sizes:
            linear_layers.append(nn.Dropout(p = drop_prob))
            linear_layers.append(nn.Linear(input_size, output_size))
            linear_layers.append(nn.ReLU())
            linear_layers.append(nn.BatchNorm1d(output_size))
            input_size = output_size
        self.linear_layers = nn.Sequential(*linear_layers)

        # Output layer        
        self.output_layer = nn.Linear(input_size, num_classes)
    
    def forward(self, x_list):
        # Process inputs by independent processign layers
        y_list = []
        for i, proc_layer in enumerate(self.proc_layers):
            y_list.append(proc_layer(x_list[i]))

        # Concat together            
        y = torch.cat(y_list, dim = 1)

        # Pass through linear layers
        z = self.linear_layers(y)

        # Get output
        o = self.output_layer(z)

        return o

# %% [markdown]
# <br>
#
#
# Aux. functions

# %%
def get_preds(logits):
    proba = torch.log_softmax(logits, dim = 1)
    _, preds = torch.max(proba, dim = 1)
    return proba, preds

def calc_acc(preds, targets):
    return torch.sum(preds == targets) / len(targets)

# %%
class ecnumTrainer():
    def __init__(self, model, train_data, eval_data = None, batch_size = 32, learning_rate = 1e-4, decay = 1e-5, device = 'cpu'):

        # Set device
        self.device = device

        # Set model
        self.model = model
        
        # Set train data loader
        self.train_loader = DataLoader(
            train_data,
            batch_size = batch_size,
            shuffle = True
        )

        # Set optimizer
        self.optimizer = Adam(
            self.model.parameters(),
            lr = learning_rate,
            weight_decay = decay
        )

        # Set eval data loader
        if eval_data is not None:
            self.eval_loader = DataLoader(
                eval_data, 
                batch_size=len(eval_data),
                shuffle = False
            )
        else:
            self.eval_loader = None

        # Set loss function
        self.loss_func = nn.CrossEntropyLoss() 

    def validate(self):
        self.model.eval()
        with torch.no_grad():
            inputs, targets = next(iter(self.eval_loader))
            inputs = [input.to(self.device) for input in inputs]
            logits = self.model(inputs)

            # Calc error
            error = self.loss_func(logits, targets)
            error = error.item()

        return logits, targets, error

    def train(self, num_epochs = 20, verbosity = 10):

        # Train track container
        train_track = {'error' : [], 'accuracy' : []}
        if self.eval_loader is not None:
            eval_track = {'error' : [], 'accuracy' : []}
            eval_preds = {}
        else:
            eval_track = None
            eval_preds = None

        # Set device
        self.model.to(self.device)
        
        # Training
        n = len(self.train_loader)
        start = time.time()
        for epoch in range(num_epochs):
            self.model.train()
            train_error = 0.    
            train_acc = 0.        
            for i, (inputs, targets) in enumerate(self.train_loader):
                inputs = [input.to(self.device) for input in inputs]
                logits = self.model(inputs)

                # Calc error and do training step
                error = self.loss_func(logits, targets)
                self.optimizer.zero_grad()
                error.backward()
                self.optimizer.step()
                error = error.item()

                # Get predictions
                _, preds = get_preds(logits)

                # Calculate accuracy
                acc = calc_acc(preds, targets)
                acc = acc.item()

                # Report
                if verbosity > 0:
                    if (i + 1) % verbosity == 0:
                        print('Epoch: {}/{}\t Batch: {}/{}\t Error: {:1.3f}\t Accuracy: {:1.2f}'.format(epoch + 1, num_epochs, i + 1, n, error, acc))

                # Increment training error and accuracy              
                train_error += error                
                train_acc += acc

            # Average training error
            train_error /= n      
            train_track['error'].append(train_error)

            # Average training accuracy
            train_acc /= n
            train_track['accuracy'].append(train_acc)

            # Validation
            if self.eval_loader is not None:
                logits, targets, error = self.validate()

                # Get predictions
                _, preds = get_preds(logits)

                # Assess accuracy
                acc = calc_acc(preds, targets)
                acc = acc.item()

                # Add to eval track
                eval_track['error'].append(error)
                eval_track['accuracy'].append(acc)

                # Add to eval preds
                eval_preds['epoch_{}'.format(epoch + 1)] = {
                    'preds' : preds.cpu().numpy(),
                    'targets' : targets.cpu().numpy()
                }

                print('\n')
                print('\t Epoch: {}'.format(epoch + 1))
                print('\t Validation loss: {:1.2f}'.format(error))
                print('\t Validation accuracy: {:1.2f}'.format(acc))
                print('\t Elapsed time: {:1.1f}'.format(time.time()-start))
                print('\n')

        return train_track, eval_track, eval_preds

# %%
class ecnumTester():
    def __init__(self, model, test_data, device = 'cpu'):

        # Set device
        self.device = device

        # Set model
        self.model = model
        
        # Set test data loader
        self.test_loader = DataLoader(
            test_data, 
            batch_size=len(test_data),
            shuffle = False
        )

        # Set loss function
        self.loss_func = nn.CrossEntropyLoss() 

    def test(self):
        self.model.eval()
        with torch.no_grad():
            inputs, targets = next(iter(self.test_loader))
            inputs = [input.to(self.device) for input in inputs]
            logits = self.model(inputs)

            # Calc error
            error = self.loss_func(logits, targets)
            error = error.item()

            # Get predictions
            proba, preds = get_preds(logits)

            # Assess accuracy
            acc = calc_acc(preds, targets)
            acc = acc.item()

        # Store targets
        self.targets = targets.cpu().numpy()
        self.proba = proba.cpu().numpy()
        self.preds = preds.cpu().numpy()
 
        return error, acc

    def get_report(self):            
        labels = list(range(self.proba.shape[1]))
        return classification_report(self.targets, self.preds, labels=labels)

    def get_confmat(self):
        labels = list(range(self.proba.shape[1]))
        conf_mat = confusion_matrix(
            self.targets, 
            self.preds,
            labels = labels
        )
        return conf_mat

    def get_roc(self):
        fpr = {}
        tpr = {}
        auroc = {}
        for i in range(self.proba.shape[1]):
            fpr[i], tpr[i], _ = roc_curve(self.targets, self.proba[:,i], pos_label = i)
            auroc[i] = auc(fpr[i], tpr[i])
        return fpr, tpr, auroc

# %%
def plot_confmat(cm, title = None, file_name = None, include_values = True):
    fig, ax = plt.subplots(figsize=(10, 7))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(ax = ax, include_values = include_values)
    
    if title is not None:
        disp.ax_.set_title(title)

    fig.tight_layout()
    if file_name is None:
        plt.show()
    else:
        plt.savefig(file_name, dpi = 100)

# %%
def plot_tracks(errors, accuracies, eval_errors = None, eval_accuracies = None, title = None, file_name = None):
    # Prepare x-values
    x = np.arange(len(errors)) + 1.
    
    # Prepare plot
    fig, ax1 = plt.subplots()
    ax1.set_xlabel('Epochs [#]')
    ax1.minorticks_on()
    ax1.grid()
    
    # Plot errors
    color = 'maroon'
    ax1.plot(x, errors, color=color)    
    ax1.set_ylabel('Cross-Entropy Loss', color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    # Plot evaluation errors
    if eval_errors:
        ax1.plot(x, eval_errors, color=color, linestyle='dashed')    

    # Plot performance
    color = 'steelblue'
    ax2 = ax1.twinx()
    ax2.plot(x, accuracies, color=color)
    ax2.set_ylabel('Accuracy', color=color)
    ax2.tick_params(axis='y', labelcolor=color)    
    # Plot evaluation accuracies
    if eval_accuracies :
        ax2.plot(x, eval_accuracies, color=color, linestyle='dashed')


    # Add title
    if title is not None:
        plt.suptitle(title)

    # Plot
    fig.tight_layout() 
    if file_name is None:
        plt.show()
    else:
        plt.savefig(file_name, dpi = 100)

# %%
def plot_rocs(fpr, tpr, auroc, title = None, file_name = None, show_legend = True):
    plt.figure()
    lw = 1
    classes = fpr.keys()
    for c in classes:                        
        plt.plot(
            fpr[c], tpr[c], 
            # color='darkorange',
            lw=lw, 
            label='Class: {}; AUROC = {:1.2f}'.format(c, auroc[c])
        )
        plt.plot([0, 1], [0, 1], color='black', lw=lw, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
    plt.grid()

    if show_legend:
        plt.legend(loc="lower right")    

    if title is not None:
        plt.title(title)

    if file_name is None:
        plt.show()
    else:
        plt.savefig(file_name, dpi = 100)

# %% [markdown]
# <br>
#
# ## Load data and create datasets (train, eval, test)

# %%
path = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/embeddings/esm_embeddings.p'
with open(path, 'rb') as f:
    esm_embedding_output = pickle.load(f)

# %%
path = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/embeddings/ProtAlbert_embeddings.p'
with open(path, 'rb') as f:
    protalbert_embedding_output = pickle.load(f)

# %%
path = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/embeddings/TAPE_embeddings.p'
with open(path, 'rb') as f:
    tape_embedding_output = pickle.load(f)

# %% [markdown]
# <br>
#
# Assert data integrity

# %%
assert esm_embedding_output['seq_data'].shape == protalbert_embedding_output['seq_data'].shape

# %%
assert tape_embedding_output['seq_data'].shape == protalbert_embedding_output['seq_data'].shape

# %% [markdown]
# <br>
#
# Select labels and inputs

# %%
labels = esm_embedding_output['seq_data'][WHICH_TARGET].values
inputs = [
    esm_embedding_output['seq_embeddings'],         # Embeddings from esm
    protalbert_embedding_output['seq_embeddings'],  # Embeddings from protAlbert
    tape_embedding_output['seq_embeddings']         # Embeddings from TAPE
]

# %% [markdown]
# <br>
#
# Sanitize against nans

# %%
nonan_idx = np.where(~np.isnan(labels))[0]
labels = labels[nonan_idx]
inputs = [input[nonan_idx] for input in inputs]

# %% [markdown]
# <br>
#
# Encode labels

# %%
ec_encoder = LabelEncoder()
labels = ec_encoder.fit_transform(np.array(labels))

# %% [markdown]
# <br>
#
# Train test split

# %%
train_idx, test_idx = train_test_split(
    range(len(labels)), 
    test_size=TEST_SIZE, 
    random_state=RANDOM_SEED
)

train_idx, eval_idx = train_test_split(
    train_idx, 
    test_size=EVAL_SIZE,
    random_state = RANDOM_SEED
)

# %% [markdown]
# <br>
#
# Create datasets

# %%
# Train data
train_labels = labels[train_idx]
train_inputs = [input[train_idx] for input in inputs]
train_dataset = seqembData(train_inputs, train_labels)

# Eval data
eval_labels = labels[eval_idx]
eval_inputs = [input[eval_idx] for input in inputs]
eval_dataset = seqembData(eval_inputs, eval_labels)

# Test data
test_labels = labels[test_idx]
test_inputs = [input[test_idx] for input in inputs]
test_dataset = seqembData(test_inputs, test_labels)

# %% [markdown]
# <br>
#
# ## Train the model

# %% [markdown]
# <br>
#
# Init model

# %%
input_sizes = [input.shape[1] for input in train_inputs]
num_classes = len(ec_encoder.classes_)
model = ecnumClassifier(
    input_sizes = input_sizes, 
    num_classes = num_classes,
    hidden_size = 256,
    linear_sizes = [512, 512, 64],
    drop_prob = .4
)

# %%
model = model.float()

# %% [markdown]
# <br>
#
# Select device

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# <br>
#
# Init trainer

# %%
trainer = ecnumTrainer(
    model,
    train_dataset,
    eval_dataset,
    batch_size = 32,
    learning_rate = 1e-4,
    device = device,
)

# %%
train_track, eval_track, eval_preds = trainer.train(num_epochs = 50, verbosity = 25)
# Out:
# Epoch: 1/50	 Batch: 25/371	 Error: 3.360	 Accuracy: 0.03
# Epoch: 1/50	 Batch: 50/371	 Error: 3.192	 Accuracy: 0.03
# Epoch: 1/50	 Batch: 75/371	 Error: 3.175	 Accuracy: 0.03
# Epoch: 1/50	 Batch: 100/371	 Error: 3.183	 Accuracy: 0.19
# Epoch: 1/50	 Batch: 125/371	 Error: 3.228	 Accuracy: 0.06
# Epoch: 1/50	 Batch: 150/371	 Error: 3.234	 Accuracy: 0.06
# Epoch: 1/50	 Batch: 175/371	 Error: 3.098	 Accuracy: 0.12
# Epoch: 1/50	 Batch: 200/371	 Error: 3.237	 Accuracy: 0.06
# Epoch: 1/50	 Batch: 225/371	 Error: 3.130	 Accuracy: 0.16
# Epoch: 1/50	 Batch: 250/371	 Error: 2.994	 Accuracy: 0.16
# Epoch: 1/50	 Batch: 275/371	 Error: 2.783	 Accuracy: 0.22
# Epoch: 1/50	 Batch: 300/371	 Error: 2.803	 Accuracy: 0.28
# Epoch: 1/50	 Batch: 325/371	 Error: 3.212	 Accuracy: 0.03
# Epoch: 1/50	 Batch: 350/371	 Error: 2.731	 Accuracy: 0.28
#
#
# 	 Epoch: 1
# 	 Validation loss: 2.85
# 	 Validation accuracy: 0.26
# 	 Elapsed time: 19.2
#
#
# Epoch: 2/50	 Batch: 25/371	 Error: 2.802	 Accuracy: 0.19
# Epoch: 2/50	 Batch: 50/371	 Error: 2.818	 Accuracy: 0.22
# Epoch: 2/50	 Batch: 75/371	 Error: 2.823	 Accuracy: 0.38
# Epoch: 2/50	 Batch: 100/371	 Error: 2.957	 Accuracy: 0.25
# Epoch: 2/50	 Batch: 125/371	 Error: 2.602	 Accuracy: 0.34
# Epoch: 2/50	 Batch: 150/371	 Error: 2.724	 Accuracy: 0.31
# Epoch: 2/50	 Batch: 175/371	 Error: 2.952	 Accuracy: 0.16
# Epoch: 2/50	 Batch: 200/371	 Error: 2.527	 Accuracy: 0.34
# Epoch: 2/50	 Batch: 225/371	 Error: 2.505	 Accuracy: 0.28
# Epoch: 2/50	 Batch: 250/371	 Error: 2.475	 Accuracy: 0.31
# Epoch: 2/50	 Batch: 275/371	 Error: 2.771	 Accuracy: 0.34
# Epoch: 2/50	 Batch: 300/371	 Error: 2.704	 Accuracy: 0.28
# Epoch: 2/50	 Batch: 325/371	 Error: 2.242	 Accuracy: 0.53
# Epoch: 2/50	 Batch: 350/371	 Error: 2.420	 Accuracy: 0.47
#
#
# 	 Epoch: 2
# 	 Validation loss: 2.32
# 	 Validation accuracy: 0.38
# 	 Elapsed time: 32.4
#
#
# Epoch: 3/50	 Batch: 25/371	 Error: 2.283	 Accuracy: 0.41
# Epoch: 3/50	 Batch: 50/371	 Error: 2.449	 Accuracy: 0.34
# Epoch: 3/50	 Batch: 75/371	 Error: 2.307	 Accuracy: 0.44
# Epoch: 3/50	 Batch: 100/371	 Error: 2.576	 Accuracy: 0.25
# Epoch: 3/50	 Batch: 125/371	 Error: 1.988	 Accuracy: 0.53
# Epoch: 3/50	 Batch: 150/371	 Error: 2.889	 Accuracy: 0.22
# Epoch: 3/50	 Batch: 175/371	 Error: 2.319	 Accuracy: 0.47
# Epoch: 3/50	 Batch: 200/371	 Error: 2.282	 Accuracy: 0.28
# Epoch: 3/50	 Batch: 225/371	 Error: 2.199	 Accuracy: 0.47
# Epoch: 3/50	 Batch: 250/371	 Error: 2.337	 Accuracy: 0.47
# Epoch: 3/50	 Batch: 275/371	 Error: 2.537	 Accuracy: 0.31
# Epoch: 3/50	 Batch: 300/371	 Error: 3.101	 Accuracy: 0.16
# Epoch: 3/50	 Batch: 325/371	 Error: 1.870	 Accuracy: 0.56
# Epoch: 3/50	 Batch: 350/371	 Error: 2.307	 Accuracy: 0.47
#
#
# 	 Epoch: 3
# 	 Validation loss: 1.88
# 	 Validation accuracy: 0.50
# 	 Elapsed time: 45.4
#
#
# Epoch: 4/50	 Batch: 25/371	 Error: 2.136	 Accuracy: 0.50
# Epoch: 4/50	 Batch: 50/371	 Error: 2.285	 Accuracy: 0.41
# Epoch: 4/50	 Batch: 75/371	 Error: 2.031	 Accuracy: 0.44
# Epoch: 4/50	 Batch: 100/371	 Error: 2.051	 Accuracy: 0.41
# Epoch: 4/50	 Batch: 125/371	 Error: 2.072	 Accuracy: 0.25
# Epoch: 4/50	 Batch: 150/371	 Error: 1.890	 Accuracy: 0.50
# Epoch: 4/50	 Batch: 175/371	 Error: 1.772	 Accuracy: 0.69
# Epoch: 4/50	 Batch: 200/371	 Error: 1.779	 Accuracy: 0.59
# Epoch: 4/50	 Batch: 225/371	 Error: 1.813	 Accuracy: 0.44
# Epoch: 4/50	 Batch: 250/371	 Error: 2.050	 Accuracy: 0.44
# Epoch: 4/50	 Batch: 275/371	 Error: 1.824	 Accuracy: 0.47
# Epoch: 4/50	 Batch: 300/371	 Error: 2.048	 Accuracy: 0.44
# Epoch: 4/50	 Batch: 325/371	 Error: 1.743	 Accuracy: 0.50
# Epoch: 4/50	 Batch: 350/371	 Error: 1.707	 Accuracy: 0.50
#
#
# 	 Epoch: 4
# 	 Validation loss: 1.56
# 	 Validation accuracy: 0.56
# 	 Elapsed time: 58.6
#
#
# Epoch: 5/50	 Batch: 25/371	 Error: 1.276	 Accuracy: 0.72
# Epoch: 5/50	 Batch: 50/371	 Error: 1.638	 Accuracy: 0.59
# Epoch: 5/50	 Batch: 75/371	 Error: 1.746	 Accuracy: 0.50
# Epoch: 5/50	 Batch: 100/371	 Error: 2.115	 Accuracy: 0.38
# Epoch: 5/50	 Batch: 125/371	 Error: 1.477	 Accuracy: 0.56
# Epoch: 5/50	 Batch: 150/371	 Error: 1.787	 Accuracy: 0.56
# Epoch: 5/50	 Batch: 175/371	 Error: 2.404	 Accuracy: 0.34
# Epoch: 5/50	 Batch: 200/371	 Error: 1.844	 Accuracy: 0.44
# Epoch: 5/50	 Batch: 225/371	 Error: 1.541	 Accuracy: 0.56
# Epoch: 5/50	 Batch: 250/371	 Error: 1.665	 Accuracy: 0.59
# Epoch: 5/50	 Batch: 275/371	 Error: 1.784	 Accuracy: 0.47
# Epoch: 5/50	 Batch: 300/371	 Error: 1.610	 Accuracy: 0.50
# Epoch: 5/50	 Batch: 325/371	 Error: 1.533	 Accuracy: 0.56
# Epoch: 5/50	 Batch: 350/371	 Error: 1.534	 Accuracy: 0.62
#
#
# 	 Epoch: 5
# 	 Validation loss: 1.36
# 	 Validation accuracy: 0.60
# 	 Elapsed time: 71.8
#
#
# Epoch: 6/50	 Batch: 25/371	 Error: 1.351	 Accuracy: 0.56
# Epoch: 6/50	 Batch: 50/371	 Error: 1.846	 Accuracy: 0.50
# Epoch: 6/50	 Batch: 75/371	 Error: 1.522	 Accuracy: 0.53
# Epoch: 6/50	 Batch: 100/371	 Error: 1.529	 Accuracy: 0.59
# Epoch: 6/50	 Batch: 125/371	 Error: 1.383	 Accuracy: 0.62
# Epoch: 6/50	 Batch: 150/371	 Error: 1.418	 Accuracy: 0.62
# Epoch: 6/50	 Batch: 175/371	 Error: 2.456	 Accuracy: 0.38
# Epoch: 6/50	 Batch: 200/371	 Error: 1.855	 Accuracy: 0.50
# Epoch: 6/50	 Batch: 225/371	 Error: 1.279	 Accuracy: 0.69
# Epoch: 6/50	 Batch: 250/371	 Error: 1.663	 Accuracy: 0.44
# Epoch: 6/50	 Batch: 275/371	 Error: 1.737	 Accuracy: 0.50
# Epoch: 6/50	 Batch: 300/371	 Error: 1.882	 Accuracy: 0.44
# Epoch: 6/50	 Batch: 325/371	 Error: 1.430	 Accuracy: 0.56
# Epoch: 6/50	 Batch: 350/371	 Error: 1.448	 Accuracy: 0.59
#
#
# 	 Epoch: 6
# 	 Validation loss: 1.21
# 	 Validation accuracy: 0.65
# 	 Elapsed time: 85.0
#
#
# Epoch: 7/50	 Batch: 25/371	 Error: 1.453	 Accuracy: 0.50
# Epoch: 7/50	 Batch: 50/371	 Error: 1.464	 Accuracy: 0.59
# Epoch: 7/50	 Batch: 75/371	 Error: 0.985	 Accuracy: 0.72
# Epoch: 7/50	 Batch: 100/371	 Error: 1.458	 Accuracy: 0.62
# Epoch: 7/50	 Batch: 125/371	 Error: 1.074	 Accuracy: 0.62
# Epoch: 7/50	 Batch: 150/371	 Error: 1.185	 Accuracy: 0.59
# Epoch: 7/50	 Batch: 175/371	 Error: 1.331	 Accuracy: 0.56
# Epoch: 7/50	 Batch: 200/371	 Error: 1.214	 Accuracy: 0.59
# Epoch: 7/50	 Batch: 225/371	 Error: 0.959	 Accuracy: 0.66
# Epoch: 7/50	 Batch: 250/371	 Error: 1.419	 Accuracy: 0.59
# Epoch: 7/50	 Batch: 275/371	 Error: 1.454	 Accuracy: 0.59
# Epoch: 7/50	 Batch: 300/371	 Error: 1.851	 Accuracy: 0.50
# Epoch: 7/50	 Batch: 325/371	 Error: 1.412	 Accuracy: 0.66
# Epoch: 7/50	 Batch: 350/371	 Error: 1.251	 Accuracy: 0.69
#
#
# 	 Epoch: 7
# 	 Validation loss: 1.10
# 	 Validation accuracy: 0.68
# 	 Elapsed time: 98.4
#
#
# Epoch: 8/50	 Batch: 25/371	 Error: 1.025	 Accuracy: 0.69
# Epoch: 8/50	 Batch: 50/371	 Error: 1.728	 Accuracy: 0.50
# Epoch: 8/50	 Batch: 75/371	 Error: 1.332	 Accuracy: 0.66
# Epoch: 8/50	 Batch: 100/371	 Error: 1.281	 Accuracy: 0.62
# Epoch: 8/50	 Batch: 125/371	 Error: 1.259	 Accuracy: 0.66
# Epoch: 8/50	 Batch: 150/371	 Error: 1.058	 Accuracy: 0.75
# Epoch: 8/50	 Batch: 175/371	 Error: 1.322	 Accuracy: 0.59
# Epoch: 8/50	 Batch: 200/371	 Error: 1.178	 Accuracy: 0.56
# Epoch: 8/50	 Batch: 225/371	 Error: 1.030	 Accuracy: 0.66
# Epoch: 8/50	 Batch: 250/371	 Error: 1.686	 Accuracy: 0.53
# Epoch: 8/50	 Batch: 275/371	 Error: 1.431	 Accuracy: 0.50
# Epoch: 8/50	 Batch: 300/371	 Error: 1.696	 Accuracy: 0.50
# Epoch: 8/50	 Batch: 325/371	 Error: 1.199	 Accuracy: 0.59
# Epoch: 8/50	 Batch: 350/371	 Error: 1.248	 Accuracy: 0.62
#
#
# 	 Epoch: 8
# 	 Validation loss: 1.01
# 	 Validation accuracy: 0.70
# 	 Elapsed time: 111.5
#
#
# Epoch: 9/50	 Batch: 25/371	 Error: 1.676	 Accuracy: 0.56
# Epoch: 9/50	 Batch: 50/371	 Error: 1.484	 Accuracy: 0.50
# Epoch: 9/50	 Batch: 75/371	 Error: 1.508	 Accuracy: 0.50
# Epoch: 9/50	 Batch: 100/371	 Error: 0.946	 Accuracy: 0.69
# Epoch: 9/50	 Batch: 125/371	 Error: 0.980	 Accuracy: 0.81
# Epoch: 9/50	 Batch: 150/371	 Error: 1.614	 Accuracy: 0.47
# Epoch: 9/50	 Batch: 175/371	 Error: 1.199	 Accuracy: 0.69
# Epoch: 9/50	 Batch: 200/371	 Error: 1.224	 Accuracy: 0.66
# Epoch: 9/50	 Batch: 225/371	 Error: 1.067	 Accuracy: 0.72
# Epoch: 9/50	 Batch: 250/371	 Error: 0.693	 Accuracy: 0.78
# Epoch: 9/50	 Batch: 275/371	 Error: 0.904	 Accuracy: 0.72
# Epoch: 9/50	 Batch: 300/371	 Error: 1.650	 Accuracy: 0.62
# Epoch: 9/50	 Batch: 325/371	 Error: 1.381	 Accuracy: 0.62
# Epoch: 9/50	 Batch: 350/371	 Error: 0.877	 Accuracy: 0.75
#
#
# 	 Epoch: 9
# 	 Validation loss: 0.96
# 	 Validation accuracy: 0.72
# 	 Elapsed time: 124.6
#
#
# Epoch: 10/50	 Batch: 25/371	 Error: 1.243	 Accuracy: 0.59
# Epoch: 10/50	 Batch: 50/371	 Error: 1.414	 Accuracy: 0.53
# Epoch: 10/50	 Batch: 75/371	 Error: 1.486	 Accuracy: 0.53
# Epoch: 10/50	 Batch: 100/371	 Error: 0.766	 Accuracy: 0.78
# Epoch: 10/50	 Batch: 125/371	 Error: 1.139	 Accuracy: 0.62
# Epoch: 10/50	 Batch: 150/371	 Error: 1.012	 Accuracy: 0.66
# Epoch: 10/50	 Batch: 175/371	 Error: 1.260	 Accuracy: 0.66
# Epoch: 10/50	 Batch: 200/371	 Error: 1.438	 Accuracy: 0.56
# Epoch: 10/50	 Batch: 225/371	 Error: 0.731	 Accuracy: 0.78
# Epoch: 10/50	 Batch: 250/371	 Error: 1.532	 Accuracy: 0.44
# Epoch: 10/50	 Batch: 275/371	 Error: 1.218	 Accuracy: 0.62
# Epoch: 10/50	 Batch: 300/371	 Error: 1.262	 Accuracy: 0.62
# Epoch: 10/50	 Batch: 325/371	 Error: 0.908	 Accuracy: 0.69
# Epoch: 10/50	 Batch: 350/371	 Error: 1.206	 Accuracy: 0.66
#
#
# 	 Epoch: 10
# 	 Validation loss: 0.92
# 	 Validation accuracy: 0.72
# 	 Elapsed time: 138.4
#
#
# Epoch: 11/50	 Batch: 25/371	 Error: 0.680	 Accuracy: 0.81
# Epoch: 11/50	 Batch: 50/371	 Error: 0.864	 Accuracy: 0.81
# Epoch: 11/50	 Batch: 75/371	 Error: 0.990	 Accuracy: 0.69
# Epoch: 11/50	 Batch: 100/371	 Error: 0.920	 Accuracy: 0.78
# Epoch: 11/50	 Batch: 125/371	 Error: 1.095	 Accuracy: 0.62
# Epoch: 11/50	 Batch: 150/371	 Error: 1.000	 Accuracy: 0.69
# Epoch: 11/50	 Batch: 175/371	 Error: 1.069	 Accuracy: 0.69
# Epoch: 11/50	 Batch: 200/371	 Error: 1.078	 Accuracy: 0.66
# Epoch: 11/50	 Batch: 225/371	 Error: 0.987	 Accuracy: 0.69
# Epoch: 11/50	 Batch: 250/371	 Error: 0.945	 Accuracy: 0.72
# Epoch: 11/50	 Batch: 275/371	 Error: 1.446	 Accuracy: 0.59
# Epoch: 11/50	 Batch: 300/371	 Error: 1.027	 Accuracy: 0.69
# Epoch: 11/50	 Batch: 325/371	 Error: 1.295	 Accuracy: 0.62
# Epoch: 11/50	 Batch: 350/371	 Error: 1.092	 Accuracy: 0.69
#
#
# 	 Epoch: 11
# 	 Validation loss: 0.90
# 	 Validation accuracy: 0.73
# 	 Elapsed time: 151.6
#
#
# Epoch: 12/50	 Batch: 25/371	 Error: 0.592	 Accuracy: 0.84
# Epoch: 12/50	 Batch: 50/371	 Error: 1.109	 Accuracy: 0.62
# Epoch: 12/50	 Batch: 75/371	 Error: 0.957	 Accuracy: 0.75
# Epoch: 12/50	 Batch: 100/371	 Error: 1.091	 Accuracy: 0.72
# Epoch: 12/50	 Batch: 125/371	 Error: 1.701	 Accuracy: 0.56
# Epoch: 12/50	 Batch: 150/371	 Error: 0.691	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 175/371	 Error: 0.990	 Accuracy: 0.66
# Epoch: 12/50	 Batch: 200/371	 Error: 1.091	 Accuracy: 0.66
# Epoch: 12/50	 Batch: 225/371	 Error: 0.749	 Accuracy: 0.78
# Epoch: 12/50	 Batch: 250/371	 Error: 0.728	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 275/371	 Error: 0.985	 Accuracy: 0.62
# Epoch: 12/50	 Batch: 300/371	 Error: 0.925	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 325/371	 Error: 1.018	 Accuracy: 0.75
# Epoch: 12/50	 Batch: 350/371	 Error: 0.901	 Accuracy: 0.78
#
#
# 	 Epoch: 12
# 	 Validation loss: 0.87
# 	 Validation accuracy: 0.73
# 	 Elapsed time: 164.6
#
#
# Epoch: 13/50	 Batch: 25/371	 Error: 0.871	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 50/371	 Error: 1.146	 Accuracy: 0.69
# Epoch: 13/50	 Batch: 75/371	 Error: 1.130	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 100/371	 Error: 1.036	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 125/371	 Error: 0.946	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 150/371	 Error: 0.683	 Accuracy: 0.91
# Epoch: 13/50	 Batch: 175/371	 Error: 1.126	 Accuracy: 0.69
# Epoch: 13/50	 Batch: 200/371	 Error: 1.026	 Accuracy: 0.69
# Epoch: 13/50	 Batch: 225/371	 Error: 0.713	 Accuracy: 0.88
# Epoch: 13/50	 Batch: 250/371	 Error: 1.199	 Accuracy: 0.69
# Epoch: 13/50	 Batch: 275/371	 Error: 0.975	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 300/371	 Error: 0.832	 Accuracy: 0.69
# Epoch: 13/50	 Batch: 325/371	 Error: 0.806	 Accuracy: 0.72
# Epoch: 13/50	 Batch: 350/371	 Error: 1.299	 Accuracy: 0.62
#
#
# 	 Epoch: 13
# 	 Validation loss: 0.82
# 	 Validation accuracy: 0.75
# 	 Elapsed time: 177.5
#
#
# Epoch: 14/50	 Batch: 25/371	 Error: 0.910	 Accuracy: 0.66
# Epoch: 14/50	 Batch: 50/371	 Error: 0.995	 Accuracy: 0.66
# Epoch: 14/50	 Batch: 75/371	 Error: 1.204	 Accuracy: 0.53
# Epoch: 14/50	 Batch: 100/371	 Error: 1.001	 Accuracy: 0.66
# Epoch: 14/50	 Batch: 125/371	 Error: 0.857	 Accuracy: 0.59
# Epoch: 14/50	 Batch: 150/371	 Error: 1.229	 Accuracy: 0.56
# Epoch: 14/50	 Batch: 175/371	 Error: 0.776	 Accuracy: 0.75
# Epoch: 14/50	 Batch: 200/371	 Error: 1.205	 Accuracy: 0.56
# Epoch: 14/50	 Batch: 225/371	 Error: 1.035	 Accuracy: 0.69
# Epoch: 14/50	 Batch: 250/371	 Error: 1.183	 Accuracy: 0.62
# Epoch: 14/50	 Batch: 275/371	 Error: 0.581	 Accuracy: 0.91
# Epoch: 14/50	 Batch: 300/371	 Error: 0.906	 Accuracy: 0.72
# Epoch: 14/50	 Batch: 325/371	 Error: 1.068	 Accuracy: 0.62
# Epoch: 14/50	 Batch: 350/371	 Error: 0.823	 Accuracy: 0.75
#
#
# 	 Epoch: 14
# 	 Validation loss: 0.83
# 	 Validation accuracy: 0.74
# 	 Elapsed time: 190.4
#
#
# Epoch: 15/50	 Batch: 25/371	 Error: 0.670	 Accuracy: 0.75
# Epoch: 15/50	 Batch: 50/371	 Error: 0.907	 Accuracy: 0.69
# Epoch: 15/50	 Batch: 75/371	 Error: 0.839	 Accuracy: 0.75
# Epoch: 15/50	 Batch: 100/371	 Error: 1.062	 Accuracy: 0.69
# Epoch: 15/50	 Batch: 125/371	 Error: 0.929	 Accuracy: 0.75
# Epoch: 15/50	 Batch: 150/371	 Error: 1.140	 Accuracy: 0.59
# Epoch: 15/50	 Batch: 175/371	 Error: 0.746	 Accuracy: 0.75
# Epoch: 15/50	 Batch: 200/371	 Error: 0.717	 Accuracy: 0.78
# Epoch: 15/50	 Batch: 225/371	 Error: 0.910	 Accuracy: 0.66
# Epoch: 15/50	 Batch: 250/371	 Error: 1.039	 Accuracy: 0.69
# Epoch: 15/50	 Batch: 275/371	 Error: 1.225	 Accuracy: 0.66
# Epoch: 15/50	 Batch: 300/371	 Error: 0.690	 Accuracy: 0.81
# Epoch: 15/50	 Batch: 325/371	 Error: 0.909	 Accuracy: 0.69
# Epoch: 15/50	 Batch: 350/371	 Error: 0.812	 Accuracy: 0.72
#
#
# 	 Epoch: 15
# 	 Validation loss: 0.80
# 	 Validation accuracy: 0.75
# 	 Elapsed time: 204.0
#
#
# Epoch: 16/50	 Batch: 25/371	 Error: 0.586	 Accuracy: 0.75
# Epoch: 16/50	 Batch: 50/371	 Error: 0.898	 Accuracy: 0.72
# Epoch: 16/50	 Batch: 75/371	 Error: 0.607	 Accuracy: 0.84
# Epoch: 16/50	 Batch: 100/371	 Error: 0.859	 Accuracy: 0.75
# Epoch: 16/50	 Batch: 125/371	 Error: 0.714	 Accuracy: 0.78
# Epoch: 16/50	 Batch: 150/371	 Error: 1.297	 Accuracy: 0.59
# Epoch: 16/50	 Batch: 175/371	 Error: 0.767	 Accuracy: 0.81
# Epoch: 16/50	 Batch: 200/371	 Error: 0.509	 Accuracy: 0.84
# Epoch: 16/50	 Batch: 225/371	 Error: 0.900	 Accuracy: 0.78
# Epoch: 16/50	 Batch: 250/371	 Error: 1.044	 Accuracy: 0.66
# Epoch: 16/50	 Batch: 275/371	 Error: 0.591	 Accuracy: 0.88
# Epoch: 16/50	 Batch: 300/371	 Error: 0.883	 Accuracy: 0.78
# Epoch: 16/50	 Batch: 325/371	 Error: 0.800	 Accuracy: 0.78
# Epoch: 16/50	 Batch: 350/371	 Error: 1.016	 Accuracy: 0.72
#
#
# 	 Epoch: 16
# 	 Validation loss: 0.77
# 	 Validation accuracy: 0.76
# 	 Elapsed time: 217.2
#
#
# Epoch: 17/50	 Batch: 25/371	 Error: 0.767	 Accuracy: 0.81
# Epoch: 17/50	 Batch: 50/371	 Error: 1.095	 Accuracy: 0.75
# Epoch: 17/50	 Batch: 75/371	 Error: 1.177	 Accuracy: 0.72
# Epoch: 17/50	 Batch: 100/371	 Error: 1.044	 Accuracy: 0.59
# Epoch: 17/50	 Batch: 125/371	 Error: 0.886	 Accuracy: 0.72
# Epoch: 17/50	 Batch: 150/371	 Error: 1.098	 Accuracy: 0.66
# Epoch: 17/50	 Batch: 175/371	 Error: 0.858	 Accuracy: 0.69
# Epoch: 17/50	 Batch: 200/371	 Error: 0.637	 Accuracy: 0.88
# Epoch: 17/50	 Batch: 225/371	 Error: 0.928	 Accuracy: 0.78
# Epoch: 17/50	 Batch: 250/371	 Error: 1.088	 Accuracy: 0.62
# Epoch: 17/50	 Batch: 275/371	 Error: 0.495	 Accuracy: 0.91
# Epoch: 17/50	 Batch: 300/371	 Error: 0.883	 Accuracy: 0.69
# Epoch: 17/50	 Batch: 325/371	 Error: 0.843	 Accuracy: 0.75
# Epoch: 17/50	 Batch: 350/371	 Error: 0.730	 Accuracy: 0.78
#
#
# 	 Epoch: 17
# 	 Validation loss: 0.75
# 	 Validation accuracy: 0.77
# 	 Elapsed time: 230.2
#
#
# Epoch: 18/50	 Batch: 25/371	 Error: 1.044	 Accuracy: 0.66
# Epoch: 18/50	 Batch: 50/371	 Error: 0.634	 Accuracy: 0.72
# Epoch: 18/50	 Batch: 75/371	 Error: 1.057	 Accuracy: 0.66
# Epoch: 18/50	 Batch: 100/371	 Error: 0.768	 Accuracy: 0.72
# Epoch: 18/50	 Batch: 125/371	 Error: 0.661	 Accuracy: 0.81
# Epoch: 18/50	 Batch: 150/371	 Error: 0.984	 Accuracy: 0.66
# Epoch: 18/50	 Batch: 175/371	 Error: 0.699	 Accuracy: 0.75
# Epoch: 18/50	 Batch: 200/371	 Error: 0.516	 Accuracy: 0.84
# Epoch: 18/50	 Batch: 225/371	 Error: 0.866	 Accuracy: 0.72
# Epoch: 18/50	 Batch: 250/371	 Error: 1.051	 Accuracy: 0.69
# Epoch: 18/50	 Batch: 275/371	 Error: 0.860	 Accuracy: 0.69
# Epoch: 18/50	 Batch: 300/371	 Error: 1.057	 Accuracy: 0.75
# Epoch: 18/50	 Batch: 325/371	 Error: 1.382	 Accuracy: 0.69
# Epoch: 18/50	 Batch: 350/371	 Error: 1.203	 Accuracy: 0.69
#
#
# 	 Epoch: 18
# 	 Validation loss: 0.76
# 	 Validation accuracy: 0.77
# 	 Elapsed time: 243.1
#
#
# Epoch: 19/50	 Batch: 25/371	 Error: 0.744	 Accuracy: 0.75
# Epoch: 19/50	 Batch: 50/371	 Error: 0.795	 Accuracy: 0.72
# Epoch: 19/50	 Batch: 75/371	 Error: 0.999	 Accuracy: 0.66
# Epoch: 19/50	 Batch: 100/371	 Error: 0.627	 Accuracy: 0.88
# Epoch: 19/50	 Batch: 125/371	 Error: 1.223	 Accuracy: 0.62
# Epoch: 19/50	 Batch: 150/371	 Error: 0.782	 Accuracy: 0.75
# Epoch: 19/50	 Batch: 175/371	 Error: 1.111	 Accuracy: 0.56
# Epoch: 19/50	 Batch: 200/371	 Error: 0.842	 Accuracy: 0.72
# Epoch: 19/50	 Batch: 225/371	 Error: 0.946	 Accuracy: 0.75
# Epoch: 19/50	 Batch: 250/371	 Error: 0.820	 Accuracy: 0.69
# Epoch: 19/50	 Batch: 275/371	 Error: 0.640	 Accuracy: 0.78
# Epoch: 19/50	 Batch: 300/371	 Error: 0.735	 Accuracy: 0.75
# Epoch: 19/50	 Batch: 325/371	 Error: 0.931	 Accuracy: 0.72
# Epoch: 19/50	 Batch: 350/371	 Error: 1.127	 Accuracy: 0.69
#
#
# 	 Epoch: 19
# 	 Validation loss: 0.73
# 	 Validation accuracy: 0.78
# 	 Elapsed time: 256.5
#
#
# Epoch: 20/50	 Batch: 25/371	 Error: 0.785	 Accuracy: 0.81
# Epoch: 20/50	 Batch: 50/371	 Error: 0.823	 Accuracy: 0.75
# Epoch: 20/50	 Batch: 75/371	 Error: 0.963	 Accuracy: 0.62
# Epoch: 20/50	 Batch: 100/371	 Error: 1.073	 Accuracy: 0.62
# Epoch: 20/50	 Batch: 125/371	 Error: 0.441	 Accuracy: 0.91
# Epoch: 20/50	 Batch: 150/371	 Error: 0.654	 Accuracy: 0.81
# Epoch: 20/50	 Batch: 175/371	 Error: 0.876	 Accuracy: 0.72
# Epoch: 20/50	 Batch: 200/371	 Error: 0.635	 Accuracy: 0.81
# Epoch: 20/50	 Batch: 225/371	 Error: 0.486	 Accuracy: 0.81
# Epoch: 20/50	 Batch: 250/371	 Error: 1.152	 Accuracy: 0.66
# Epoch: 20/50	 Batch: 275/371	 Error: 1.016	 Accuracy: 0.69
# Epoch: 20/50	 Batch: 300/371	 Error: 0.879	 Accuracy: 0.75
# Epoch: 20/50	 Batch: 325/371	 Error: 0.769	 Accuracy: 0.66
# Epoch: 20/50	 Batch: 350/371	 Error: 0.375	 Accuracy: 0.91
#
#
# 	 Epoch: 20
# 	 Validation loss: 0.71
# 	 Validation accuracy: 0.79
# 	 Elapsed time: 269.7
#
#
# Epoch: 21/50	 Batch: 25/371	 Error: 0.572	 Accuracy: 0.81
# Epoch: 21/50	 Batch: 50/371	 Error: 0.688	 Accuracy: 0.81
# Epoch: 21/50	 Batch: 75/371	 Error: 1.038	 Accuracy: 0.62
# Epoch: 21/50	 Batch: 100/371	 Error: 0.672	 Accuracy: 0.75
# Epoch: 21/50	 Batch: 125/371	 Error: 0.569	 Accuracy: 0.78
# Epoch: 21/50	 Batch: 150/371	 Error: 1.014	 Accuracy: 0.72
# Epoch: 21/50	 Batch: 175/371	 Error: 0.744	 Accuracy: 0.78
# Epoch: 21/50	 Batch: 200/371	 Error: 0.670	 Accuracy: 0.78
# Epoch: 21/50	 Batch: 225/371	 Error: 0.942	 Accuracy: 0.75
# Epoch: 21/50	 Batch: 250/371	 Error: 0.762	 Accuracy: 0.75
# Epoch: 21/50	 Batch: 275/371	 Error: 0.793	 Accuracy: 0.69
# Epoch: 21/50	 Batch: 300/371	 Error: 0.611	 Accuracy: 0.75
# Epoch: 21/50	 Batch: 325/371	 Error: 0.615	 Accuracy: 0.78
# Epoch: 21/50	 Batch: 350/371	 Error: 0.781	 Accuracy: 0.78
#
#
# 	 Epoch: 21
# 	 Validation loss: 0.72
# 	 Validation accuracy: 0.78
# 	 Elapsed time: 282.8
#
#
# Epoch: 22/50	 Batch: 25/371	 Error: 0.871	 Accuracy: 0.75
# Epoch: 22/50	 Batch: 50/371	 Error: 0.717	 Accuracy: 0.72
# Epoch: 22/50	 Batch: 75/371	 Error: 0.548	 Accuracy: 0.78
# Epoch: 22/50	 Batch: 100/371	 Error: 0.763	 Accuracy: 0.75
# Epoch: 22/50	 Batch: 125/371	 Error: 0.919	 Accuracy: 0.66
# Epoch: 22/50	 Batch: 150/371	 Error: 1.025	 Accuracy: 0.72
# Epoch: 22/50	 Batch: 175/371	 Error: 0.729	 Accuracy: 0.69
# Epoch: 22/50	 Batch: 200/371	 Error: 0.959	 Accuracy: 0.62
# Epoch: 22/50	 Batch: 225/371	 Error: 0.339	 Accuracy: 0.94
# Epoch: 22/50	 Batch: 250/371	 Error: 0.648	 Accuracy: 0.78
# Epoch: 22/50	 Batch: 275/371	 Error: 1.085	 Accuracy: 0.62
# Epoch: 22/50	 Batch: 300/371	 Error: 1.506	 Accuracy: 0.56
# Epoch: 22/50	 Batch: 325/371	 Error: 0.536	 Accuracy: 0.84
# Epoch: 22/50	 Batch: 350/371	 Error: 0.771	 Accuracy: 0.81
#
#
# 	 Epoch: 22
# 	 Validation loss: 0.70
# 	 Validation accuracy: 0.78
# 	 Elapsed time: 296.1
#
#
# Epoch: 23/50	 Batch: 25/371	 Error: 0.925	 Accuracy: 0.75
# Epoch: 23/50	 Batch: 50/371	 Error: 0.336	 Accuracy: 0.91
# Epoch: 23/50	 Batch: 75/371	 Error: 0.556	 Accuracy: 0.78
# Epoch: 23/50	 Batch: 100/371	 Error: 0.985	 Accuracy: 0.69
# Epoch: 23/50	 Batch: 125/371	 Error: 0.792	 Accuracy: 0.81
# Epoch: 23/50	 Batch: 150/371	 Error: 0.717	 Accuracy: 0.72
# Epoch: 23/50	 Batch: 175/371	 Error: 0.891	 Accuracy: 0.69
# Epoch: 23/50	 Batch: 200/371	 Error: 1.000	 Accuracy: 0.75
# Epoch: 23/50	 Batch: 225/371	 Error: 1.066	 Accuracy: 0.62
# Epoch: 23/50	 Batch: 250/371	 Error: 0.756	 Accuracy: 0.72
# Epoch: 23/50	 Batch: 275/371	 Error: 0.488	 Accuracy: 0.91
# Epoch: 23/50	 Batch: 300/371	 Error: 0.537	 Accuracy: 0.78
# Epoch: 23/50	 Batch: 325/371	 Error: 0.719	 Accuracy: 0.81
# Epoch: 23/50	 Batch: 350/371	 Error: 0.543	 Accuracy: 0.84
#
#
# 	 Epoch: 23
# 	 Validation loss: 0.71
# 	 Validation accuracy: 0.78
# 	 Elapsed time: 309.4
#
#
# Epoch: 24/50	 Batch: 25/371	 Error: 0.400	 Accuracy: 0.91
# Epoch: 24/50	 Batch: 50/371	 Error: 0.746	 Accuracy: 0.69
# Epoch: 24/50	 Batch: 75/371	 Error: 0.531	 Accuracy: 0.81
# Epoch: 24/50	 Batch: 100/371	 Error: 0.453	 Accuracy: 0.78
# Epoch: 24/50	 Batch: 125/371	 Error: 0.475	 Accuracy: 0.81
# Epoch: 24/50	 Batch: 150/371	 Error: 0.554	 Accuracy: 0.84
# Epoch: 24/50	 Batch: 175/371	 Error: 1.169	 Accuracy: 0.66
# Epoch: 24/50	 Batch: 200/371	 Error: 0.855	 Accuracy: 0.75
# Epoch: 24/50	 Batch: 225/371	 Error: 0.635	 Accuracy: 0.75
# Epoch: 24/50	 Batch: 250/371	 Error: 0.866	 Accuracy: 0.81
# Epoch: 24/50	 Batch: 275/371	 Error: 0.593	 Accuracy: 0.81
# Epoch: 24/50	 Batch: 300/371	 Error: 0.562	 Accuracy: 0.78
# Epoch: 24/50	 Batch: 325/371	 Error: 0.954	 Accuracy: 0.72
# Epoch: 24/50	 Batch: 350/371	 Error: 0.292	 Accuracy: 0.94
#
#
# 	 Epoch: 24
# 	 Validation loss: 0.68
# 	 Validation accuracy: 0.79
# 	 Elapsed time: 323.2
#
#
# Epoch: 25/50	 Batch: 25/371	 Error: 0.650	 Accuracy: 0.78
# Epoch: 25/50	 Batch: 50/371	 Error: 0.576	 Accuracy: 0.84
# Epoch: 25/50	 Batch: 75/371	 Error: 1.127	 Accuracy: 0.69
# Epoch: 25/50	 Batch: 100/371	 Error: 0.752	 Accuracy: 0.75
# Epoch: 25/50	 Batch: 125/371	 Error: 0.689	 Accuracy: 0.75
# Epoch: 25/50	 Batch: 150/371	 Error: 0.956	 Accuracy: 0.72
# Epoch: 25/50	 Batch: 175/371	 Error: 0.647	 Accuracy: 0.72
# Epoch: 25/50	 Batch: 200/371	 Error: 0.472	 Accuracy: 0.81
# Epoch: 25/50	 Batch: 225/371	 Error: 0.920	 Accuracy: 0.84
# Epoch: 25/50	 Batch: 250/371	 Error: 0.827	 Accuracy: 0.75
# Epoch: 25/50	 Batch: 275/371	 Error: 0.655	 Accuracy: 0.81
# Epoch: 25/50	 Batch: 300/371	 Error: 0.683	 Accuracy: 0.81
# Epoch: 25/50	 Batch: 325/371	 Error: 1.009	 Accuracy: 0.72
# Epoch: 25/50	 Batch: 350/371	 Error: 1.042	 Accuracy: 0.72
#
#
# 	 Epoch: 25
# 	 Validation loss: 0.69
# 	 Validation accuracy: 0.79
# 	 Elapsed time: 336.8
#
#
# Epoch: 26/50	 Batch: 25/371	 Error: 0.652	 Accuracy: 0.84
# Epoch: 26/50	 Batch: 50/371	 Error: 0.807	 Accuracy: 0.78
# Epoch: 26/50	 Batch: 75/371	 Error: 0.902	 Accuracy: 0.78
# Epoch: 26/50	 Batch: 100/371	 Error: 0.958	 Accuracy: 0.69
# Epoch: 26/50	 Batch: 125/371	 Error: 0.596	 Accuracy: 0.84
# Epoch: 26/50	 Batch: 150/371	 Error: 0.998	 Accuracy: 0.66
# Epoch: 26/50	 Batch: 175/371	 Error: 0.577	 Accuracy: 0.84
# Epoch: 26/50	 Batch: 200/371	 Error: 0.772	 Accuracy: 0.75
# Epoch: 26/50	 Batch: 225/371	 Error: 0.557	 Accuracy: 0.78
# Epoch: 26/50	 Batch: 250/371	 Error: 0.583	 Accuracy: 0.88
# Epoch: 26/50	 Batch: 275/371	 Error: 1.030	 Accuracy: 0.59
# Epoch: 26/50	 Batch: 300/371	 Error: 1.074	 Accuracy: 0.59
# Epoch: 26/50	 Batch: 325/371	 Error: 1.112	 Accuracy: 0.72
# Epoch: 26/50	 Batch: 350/371	 Error: 0.768	 Accuracy: 0.75
#
#
# 	 Epoch: 26
# 	 Validation loss: 0.69
# 	 Validation accuracy: 0.79
# 	 Elapsed time: 350.8
#
#
# Epoch: 27/50	 Batch: 25/371	 Error: 1.171	 Accuracy: 0.69
# Epoch: 27/50	 Batch: 50/371	 Error: 0.684	 Accuracy: 0.75
# Epoch: 27/50	 Batch: 75/371	 Error: 0.662	 Accuracy: 0.84
# Epoch: 27/50	 Batch: 100/371	 Error: 0.720	 Accuracy: 0.72
# Epoch: 27/50	 Batch: 125/371	 Error: 0.709	 Accuracy: 0.78
# Epoch: 27/50	 Batch: 150/371	 Error: 0.837	 Accuracy: 0.72
# Epoch: 27/50	 Batch: 175/371	 Error: 0.911	 Accuracy: 0.62
# Epoch: 27/50	 Batch: 200/371	 Error: 1.117	 Accuracy: 0.69
# Epoch: 27/50	 Batch: 225/371	 Error: 0.530	 Accuracy: 0.84
# Epoch: 27/50	 Batch: 250/371	 Error: 0.733	 Accuracy: 0.84
# Epoch: 27/50	 Batch: 275/371	 Error: 0.631	 Accuracy: 0.75
# Epoch: 27/50	 Batch: 300/371	 Error: 1.005	 Accuracy: 0.66
# Epoch: 27/50	 Batch: 325/371	 Error: 0.891	 Accuracy: 0.62
# Epoch: 27/50	 Batch: 350/371	 Error: 0.445	 Accuracy: 0.81
#
#
# 	 Epoch: 27
# 	 Validation loss: 0.67
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 364.2
#
#
# Epoch: 28/50	 Batch: 25/371	 Error: 0.757	 Accuracy: 0.75
# Epoch: 28/50	 Batch: 50/371	 Error: 0.902	 Accuracy: 0.69
# Epoch: 28/50	 Batch: 75/371	 Error: 0.854	 Accuracy: 0.75
# Epoch: 28/50	 Batch: 100/371	 Error: 1.056	 Accuracy: 0.69
# Epoch: 28/50	 Batch: 125/371	 Error: 0.962	 Accuracy: 0.69
# Epoch: 28/50	 Batch: 150/371	 Error: 0.869	 Accuracy: 0.66
# Epoch: 28/50	 Batch: 175/371	 Error: 0.932	 Accuracy: 0.69
# Epoch: 28/50	 Batch: 200/371	 Error: 0.527	 Accuracy: 0.81
# Epoch: 28/50	 Batch: 225/371	 Error: 0.959	 Accuracy: 0.66
# Epoch: 28/50	 Batch: 250/371	 Error: 0.875	 Accuracy: 0.75
# Epoch: 28/50	 Batch: 275/371	 Error: 0.553	 Accuracy: 0.75
# Epoch: 28/50	 Batch: 300/371	 Error: 0.648	 Accuracy: 0.75
# Epoch: 28/50	 Batch: 325/371	 Error: 0.866	 Accuracy: 0.75
# Epoch: 28/50	 Batch: 350/371	 Error: 0.723	 Accuracy: 0.75
#
#
# 	 Epoch: 28
# 	 Validation loss: 0.69
# 	 Validation accuracy: 0.79
# 	 Elapsed time: 377.5
#
#
# Epoch: 29/50	 Batch: 25/371	 Error: 0.561	 Accuracy: 0.81
# Epoch: 29/50	 Batch: 50/371	 Error: 0.472	 Accuracy: 0.88
# Epoch: 29/50	 Batch: 75/371	 Error: 0.743	 Accuracy: 0.75
# Epoch: 29/50	 Batch: 100/371	 Error: 0.696	 Accuracy: 0.78
# Epoch: 29/50	 Batch: 125/371	 Error: 0.948	 Accuracy: 0.66
# Epoch: 29/50	 Batch: 150/371	 Error: 0.893	 Accuracy: 0.75
# Epoch: 29/50	 Batch: 175/371	 Error: 0.544	 Accuracy: 0.84
# Epoch: 29/50	 Batch: 200/371	 Error: 0.980	 Accuracy: 0.78
# Epoch: 29/50	 Batch: 225/371	 Error: 0.327	 Accuracy: 0.91
# Epoch: 29/50	 Batch: 250/371	 Error: 0.555	 Accuracy: 0.84
# Epoch: 29/50	 Batch: 275/371	 Error: 0.713	 Accuracy: 0.75
# Epoch: 29/50	 Batch: 300/371	 Error: 0.856	 Accuracy: 0.75
# Epoch: 29/50	 Batch: 325/371	 Error: 0.569	 Accuracy: 0.75
# Epoch: 29/50	 Batch: 350/371	 Error: 0.460	 Accuracy: 0.84
#
#
# 	 Epoch: 29
# 	 Validation loss: 0.66
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 391.0
#
#
# Epoch: 30/50	 Batch: 25/371	 Error: 0.946	 Accuracy: 0.59
# Epoch: 30/50	 Batch: 50/371	 Error: 0.939	 Accuracy: 0.75
# Epoch: 30/50	 Batch: 75/371	 Error: 0.320	 Accuracy: 0.88
# Epoch: 30/50	 Batch: 100/371	 Error: 0.817	 Accuracy: 0.69
# Epoch: 30/50	 Batch: 125/371	 Error: 0.334	 Accuracy: 0.88
# Epoch: 30/50	 Batch: 150/371	 Error: 0.937	 Accuracy: 0.72
# Epoch: 30/50	 Batch: 175/371	 Error: 0.396	 Accuracy: 0.91
# Epoch: 30/50	 Batch: 200/371	 Error: 1.080	 Accuracy: 0.69
# Epoch: 30/50	 Batch: 225/371	 Error: 0.787	 Accuracy: 0.75
# Epoch: 30/50	 Batch: 250/371	 Error: 1.037	 Accuracy: 0.69
# Epoch: 30/50	 Batch: 275/371	 Error: 0.922	 Accuracy: 0.69
# Epoch: 30/50	 Batch: 300/371	 Error: 0.764	 Accuracy: 0.69
# Epoch: 30/50	 Batch: 325/371	 Error: 0.795	 Accuracy: 0.75
# Epoch: 30/50	 Batch: 350/371	 Error: 0.440	 Accuracy: 0.84
#
#
# 	 Epoch: 30
# 	 Validation loss: 0.67
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 404.3
#
#
# Epoch: 31/50	 Batch: 25/371	 Error: 0.657	 Accuracy: 0.78
# Epoch: 31/50	 Batch: 50/371	 Error: 0.489	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 75/371	 Error: 0.441	 Accuracy: 0.88
# Epoch: 31/50	 Batch: 100/371	 Error: 0.643	 Accuracy: 0.78
# Epoch: 31/50	 Batch: 125/371	 Error: 0.690	 Accuracy: 0.81
# Epoch: 31/50	 Batch: 150/371	 Error: 0.822	 Accuracy: 0.75
# Epoch: 31/50	 Batch: 175/371	 Error: 0.540	 Accuracy: 0.81
# Epoch: 31/50	 Batch: 200/371	 Error: 0.355	 Accuracy: 0.88
# Epoch: 31/50	 Batch: 225/371	 Error: 0.781	 Accuracy: 0.72
# Epoch: 31/50	 Batch: 250/371	 Error: 0.543	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 275/371	 Error: 0.839	 Accuracy: 0.75
# Epoch: 31/50	 Batch: 300/371	 Error: 0.687	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 325/371	 Error: 0.809	 Accuracy: 0.75
# Epoch: 31/50	 Batch: 350/371	 Error: 0.707	 Accuracy: 0.78
#
#
# 	 Epoch: 31
# 	 Validation loss: 0.66
# 	 Validation accuracy: 0.79
# 	 Elapsed time: 417.8
#
#
# Epoch: 32/50	 Batch: 25/371	 Error: 0.496	 Accuracy: 0.88
# Epoch: 32/50	 Batch: 50/371	 Error: 0.576	 Accuracy: 0.84
# Epoch: 32/50	 Batch: 75/371	 Error: 0.801	 Accuracy: 0.72
# Epoch: 32/50	 Batch: 100/371	 Error: 0.727	 Accuracy: 0.72
# Epoch: 32/50	 Batch: 125/371	 Error: 0.696	 Accuracy: 0.81
# Epoch: 32/50	 Batch: 150/371	 Error: 0.518	 Accuracy: 0.78
# Epoch: 32/50	 Batch: 175/371	 Error: 0.704	 Accuracy: 0.62
# Epoch: 32/50	 Batch: 200/371	 Error: 0.696	 Accuracy: 0.75
# Epoch: 32/50	 Batch: 225/371	 Error: 0.823	 Accuracy: 0.75
# Epoch: 32/50	 Batch: 250/371	 Error: 0.528	 Accuracy: 0.78
# Epoch: 32/50	 Batch: 275/371	 Error: 0.487	 Accuracy: 0.84
# Epoch: 32/50	 Batch: 300/371	 Error: 0.740	 Accuracy: 0.75
# Epoch: 32/50	 Batch: 325/371	 Error: 0.510	 Accuracy: 0.81
# Epoch: 32/50	 Batch: 350/371	 Error: 0.532	 Accuracy: 0.81
#
#
# 	 Epoch: 32
# 	 Validation loss: 0.63
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 431.8
#
#
# Epoch: 33/50	 Batch: 25/371	 Error: 0.824	 Accuracy: 0.62
# Epoch: 33/50	 Batch: 50/371	 Error: 0.785	 Accuracy: 0.69
# Epoch: 33/50	 Batch: 75/371	 Error: 0.665	 Accuracy: 0.75
# Epoch: 33/50	 Batch: 100/371	 Error: 0.500	 Accuracy: 0.84
# Epoch: 33/50	 Batch: 125/371	 Error: 0.880	 Accuracy: 0.75
# Epoch: 33/50	 Batch: 150/371	 Error: 0.855	 Accuracy: 0.72
# Epoch: 33/50	 Batch: 175/371	 Error: 0.711	 Accuracy: 0.72
# Epoch: 33/50	 Batch: 200/371	 Error: 0.740	 Accuracy: 0.81
# Epoch: 33/50	 Batch: 225/371	 Error: 0.918	 Accuracy: 0.75
# Epoch: 33/50	 Batch: 250/371	 Error: 0.729	 Accuracy: 0.72
# Epoch: 33/50	 Batch: 275/371	 Error: 0.535	 Accuracy: 0.78
# Epoch: 33/50	 Batch: 300/371	 Error: 0.768	 Accuracy: 0.75
# Epoch: 33/50	 Batch: 325/371	 Error: 0.665	 Accuracy: 0.78
# Epoch: 33/50	 Batch: 350/371	 Error: 0.464	 Accuracy: 0.88
#
#
# 	 Epoch: 33
# 	 Validation loss: 0.65
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 445.4
#
#
# Epoch: 34/50	 Batch: 25/371	 Error: 0.419	 Accuracy: 0.88
# Epoch: 34/50	 Batch: 50/371	 Error: 0.580	 Accuracy: 0.81
# Epoch: 34/50	 Batch: 75/371	 Error: 0.335	 Accuracy: 0.81
# Epoch: 34/50	 Batch: 100/371	 Error: 0.631	 Accuracy: 0.81
# Epoch: 34/50	 Batch: 125/371	 Error: 0.257	 Accuracy: 0.94
# Epoch: 34/50	 Batch: 150/371	 Error: 0.810	 Accuracy: 0.72
# Epoch: 34/50	 Batch: 175/371	 Error: 0.439	 Accuracy: 0.84
# Epoch: 34/50	 Batch: 200/371	 Error: 0.600	 Accuracy: 0.78
# Epoch: 34/50	 Batch: 225/371	 Error: 0.611	 Accuracy: 0.88
# Epoch: 34/50	 Batch: 250/371	 Error: 0.755	 Accuracy: 0.81
# Epoch: 34/50	 Batch: 275/371	 Error: 0.820	 Accuracy: 0.75
# Epoch: 34/50	 Batch: 300/371	 Error: 0.972	 Accuracy: 0.66
# Epoch: 34/50	 Batch: 325/371	 Error: 0.655	 Accuracy: 0.78
# Epoch: 34/50	 Batch: 350/371	 Error: 0.967	 Accuracy: 0.72
#
#
# 	 Epoch: 34
# 	 Validation loss: 0.64
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 459.2
#
#
# Epoch: 35/50	 Batch: 25/371	 Error: 0.522	 Accuracy: 0.81
# Epoch: 35/50	 Batch: 50/371	 Error: 0.803	 Accuracy: 0.78
# Epoch: 35/50	 Batch: 75/371	 Error: 0.691	 Accuracy: 0.81
# Epoch: 35/50	 Batch: 100/371	 Error: 0.617	 Accuracy: 0.75
# Epoch: 35/50	 Batch: 125/371	 Error: 0.562	 Accuracy: 0.84
# Epoch: 35/50	 Batch: 150/371	 Error: 0.658	 Accuracy: 0.78
# Epoch: 35/50	 Batch: 175/371	 Error: 0.476	 Accuracy: 0.84
# Epoch: 35/50	 Batch: 200/371	 Error: 0.631	 Accuracy: 0.75
# Epoch: 35/50	 Batch: 225/371	 Error: 0.630	 Accuracy: 0.75
# Epoch: 35/50	 Batch: 250/371	 Error: 0.464	 Accuracy: 0.88
# Epoch: 35/50	 Batch: 275/371	 Error: 0.683	 Accuracy: 0.75
# Epoch: 35/50	 Batch: 300/371	 Error: 0.678	 Accuracy: 0.81
# Epoch: 35/50	 Batch: 325/371	 Error: 0.405	 Accuracy: 0.88
# Epoch: 35/50	 Batch: 350/371	 Error: 0.566	 Accuracy: 0.78
#
#
# 	 Epoch: 35
# 	 Validation loss: 0.63
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 473.0
#
#
# Epoch: 36/50	 Batch: 25/371	 Error: 0.519	 Accuracy: 0.84
# Epoch: 36/50	 Batch: 50/371	 Error: 0.536	 Accuracy: 0.78
# Epoch: 36/50	 Batch: 75/371	 Error: 1.089	 Accuracy: 0.72
# Epoch: 36/50	 Batch: 100/371	 Error: 0.536	 Accuracy: 0.81
# Epoch: 36/50	 Batch: 125/371	 Error: 0.742	 Accuracy: 0.78
# Epoch: 36/50	 Batch: 150/371	 Error: 0.394	 Accuracy: 0.88
# Epoch: 36/50	 Batch: 175/371	 Error: 0.605	 Accuracy: 0.78
# Epoch: 36/50	 Batch: 200/371	 Error: 0.925	 Accuracy: 0.72
# Epoch: 36/50	 Batch: 225/371	 Error: 1.014	 Accuracy: 0.66
# Epoch: 36/50	 Batch: 250/371	 Error: 0.535	 Accuracy: 0.78
# Epoch: 36/50	 Batch: 275/371	 Error: 0.455	 Accuracy: 0.84
# Epoch: 36/50	 Batch: 300/371	 Error: 0.508	 Accuracy: 0.84
# Epoch: 36/50	 Batch: 325/371	 Error: 0.406	 Accuracy: 0.84
# Epoch: 36/50	 Batch: 350/371	 Error: 0.607	 Accuracy: 0.78
#
#
# 	 Epoch: 36
# 	 Validation loss: 0.65
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 486.8
#
#
# Epoch: 37/50	 Batch: 25/371	 Error: 0.622	 Accuracy: 0.72
# Epoch: 37/50	 Batch: 50/371	 Error: 0.563	 Accuracy: 0.81
# Epoch: 37/50	 Batch: 75/371	 Error: 0.684	 Accuracy: 0.78
# Epoch: 37/50	 Batch: 100/371	 Error: 0.923	 Accuracy: 0.66
# Epoch: 37/50	 Batch: 125/371	 Error: 0.734	 Accuracy: 0.81
# Epoch: 37/50	 Batch: 150/371	 Error: 0.525	 Accuracy: 0.88
# Epoch: 37/50	 Batch: 175/371	 Error: 0.756	 Accuracy: 0.75
# Epoch: 37/50	 Batch: 200/371	 Error: 0.496	 Accuracy: 0.94
# Epoch: 37/50	 Batch: 225/371	 Error: 0.421	 Accuracy: 0.88
# Epoch: 37/50	 Batch: 250/371	 Error: 0.462	 Accuracy: 0.84
# Epoch: 37/50	 Batch: 275/371	 Error: 0.870	 Accuracy: 0.75
# Epoch: 37/50	 Batch: 300/371	 Error: 0.341	 Accuracy: 0.88
# Epoch: 37/50	 Batch: 325/371	 Error: 0.711	 Accuracy: 0.69
# Epoch: 37/50	 Batch: 350/371	 Error: 0.842	 Accuracy: 0.69
#
#
# 	 Epoch: 37
# 	 Validation loss: 0.64
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 501.2
#
#
# Epoch: 38/50	 Batch: 25/371	 Error: 0.398	 Accuracy: 0.81
# Epoch: 38/50	 Batch: 50/371	 Error: 0.759	 Accuracy: 0.69
# Epoch: 38/50	 Batch: 75/371	 Error: 0.649	 Accuracy: 0.78
# Epoch: 38/50	 Batch: 100/371	 Error: 0.592	 Accuracy: 0.84
# Epoch: 38/50	 Batch: 125/371	 Error: 0.528	 Accuracy: 0.81
# Epoch: 38/50	 Batch: 150/371	 Error: 0.744	 Accuracy: 0.69
# Epoch: 38/50	 Batch: 175/371	 Error: 0.385	 Accuracy: 0.88
# Epoch: 38/50	 Batch: 200/371	 Error: 0.429	 Accuracy: 0.88
# Epoch: 38/50	 Batch: 225/371	 Error: 0.727	 Accuracy: 0.72
# Epoch: 38/50	 Batch: 250/371	 Error: 0.550	 Accuracy: 0.78
# Epoch: 38/50	 Batch: 275/371	 Error: 0.681	 Accuracy: 0.81
# Epoch: 38/50	 Batch: 300/371	 Error: 0.636	 Accuracy: 0.75
# Epoch: 38/50	 Batch: 325/371	 Error: 0.705	 Accuracy: 0.75
# Epoch: 38/50	 Batch: 350/371	 Error: 0.624	 Accuracy: 0.84
#
#
# 	 Epoch: 38
# 	 Validation loss: 0.62
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 515.5
#
#
# Epoch: 39/50	 Batch: 25/371	 Error: 0.431	 Accuracy: 0.84
# Epoch: 39/50	 Batch: 50/371	 Error: 0.417	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 75/371	 Error: 0.546	 Accuracy: 0.84
# Epoch: 39/50	 Batch: 100/371	 Error: 0.709	 Accuracy: 0.75
# Epoch: 39/50	 Batch: 125/371	 Error: 0.363	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 150/371	 Error: 0.624	 Accuracy: 0.75
# Epoch: 39/50	 Batch: 175/371	 Error: 0.638	 Accuracy: 0.81
# Epoch: 39/50	 Batch: 200/371	 Error: 0.819	 Accuracy: 0.66
# Epoch: 39/50	 Batch: 225/371	 Error: 0.678	 Accuracy: 0.75
# Epoch: 39/50	 Batch: 250/371	 Error: 0.695	 Accuracy: 0.75
# Epoch: 39/50	 Batch: 275/371	 Error: 0.554	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 300/371	 Error: 0.369	 Accuracy: 0.91
# Epoch: 39/50	 Batch: 325/371	 Error: 0.393	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 350/371	 Error: 0.584	 Accuracy: 0.78
#
#
# 	 Epoch: 39
# 	 Validation loss: 0.63
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 529.4
#
#
# Epoch: 40/50	 Batch: 25/371	 Error: 0.530	 Accuracy: 0.72
# Epoch: 40/50	 Batch: 50/371	 Error: 0.750	 Accuracy: 0.81
# Epoch: 40/50	 Batch: 75/371	 Error: 0.672	 Accuracy: 0.78
# Epoch: 40/50	 Batch: 100/371	 Error: 0.784	 Accuracy: 0.66
# Epoch: 40/50	 Batch: 125/371	 Error: 0.589	 Accuracy: 0.72
# Epoch: 40/50	 Batch: 150/371	 Error: 1.021	 Accuracy: 0.66
# Epoch: 40/50	 Batch: 175/371	 Error: 0.509	 Accuracy: 0.84
# Epoch: 40/50	 Batch: 200/371	 Error: 0.450	 Accuracy: 0.84
# Epoch: 40/50	 Batch: 225/371	 Error: 0.672	 Accuracy: 0.78
# Epoch: 40/50	 Batch: 250/371	 Error: 0.601	 Accuracy: 0.88
# Epoch: 40/50	 Batch: 275/371	 Error: 0.587	 Accuracy: 0.81
# Epoch: 40/50	 Batch: 300/371	 Error: 0.499	 Accuracy: 0.75
# Epoch: 40/50	 Batch: 325/371	 Error: 0.609	 Accuracy: 0.78
# Epoch: 40/50	 Batch: 350/371	 Error: 0.502	 Accuracy: 0.88
#
#
# 	 Epoch: 40
# 	 Validation loss: 0.63
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 543.3
#
#
# Epoch: 41/50	 Batch: 25/371	 Error: 0.384	 Accuracy: 0.88
# Epoch: 41/50	 Batch: 50/371	 Error: 0.544	 Accuracy: 0.84
# Epoch: 41/50	 Batch: 75/371	 Error: 0.934	 Accuracy: 0.66
# Epoch: 41/50	 Batch: 100/371	 Error: 0.563	 Accuracy: 0.75
# Epoch: 41/50	 Batch: 125/371	 Error: 0.355	 Accuracy: 0.94
# Epoch: 41/50	 Batch: 150/371	 Error: 1.034	 Accuracy: 0.56
# Epoch: 41/50	 Batch: 175/371	 Error: 0.607	 Accuracy: 0.78
# Epoch: 41/50	 Batch: 200/371	 Error: 0.772	 Accuracy: 0.78
# Epoch: 41/50	 Batch: 225/371	 Error: 0.552	 Accuracy: 0.75
# Epoch: 41/50	 Batch: 250/371	 Error: 0.566	 Accuracy: 0.81
# Epoch: 41/50	 Batch: 275/371	 Error: 0.696	 Accuracy: 0.78
# Epoch: 41/50	 Batch: 300/371	 Error: 0.675	 Accuracy: 0.78
# Epoch: 41/50	 Batch: 325/371	 Error: 0.673	 Accuracy: 0.81
# Epoch: 41/50	 Batch: 350/371	 Error: 0.904	 Accuracy: 0.72
#
#
# 	 Epoch: 41
# 	 Validation loss: 0.61
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 557.4
#
#
# Epoch: 42/50	 Batch: 25/371	 Error: 0.319	 Accuracy: 0.91
# Epoch: 42/50	 Batch: 50/371	 Error: 0.700	 Accuracy: 0.72
# Epoch: 42/50	 Batch: 75/371	 Error: 0.480	 Accuracy: 0.78
# Epoch: 42/50	 Batch: 100/371	 Error: 1.074	 Accuracy: 0.66
# Epoch: 42/50	 Batch: 125/371	 Error: 0.802	 Accuracy: 0.81
# Epoch: 42/50	 Batch: 150/371	 Error: 0.652	 Accuracy: 0.78
# Epoch: 42/50	 Batch: 175/371	 Error: 0.561	 Accuracy: 0.78
# Epoch: 42/50	 Batch: 200/371	 Error: 0.632	 Accuracy: 0.81
# Epoch: 42/50	 Batch: 225/371	 Error: 0.286	 Accuracy: 0.91
# Epoch: 42/50	 Batch: 250/371	 Error: 0.445	 Accuracy: 0.88
# Epoch: 42/50	 Batch: 275/371	 Error: 0.511	 Accuracy: 0.84
# Epoch: 42/50	 Batch: 300/371	 Error: 0.919	 Accuracy: 0.62
# Epoch: 42/50	 Batch: 325/371	 Error: 0.567	 Accuracy: 0.78
# Epoch: 42/50	 Batch: 350/371	 Error: 0.700	 Accuracy: 0.75
#
#
# 	 Epoch: 42
# 	 Validation loss: 0.63
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 571.7
#
#
# Epoch: 43/50	 Batch: 25/371	 Error: 0.439	 Accuracy: 0.84
# Epoch: 43/50	 Batch: 50/371	 Error: 0.652	 Accuracy: 0.81
# Epoch: 43/50	 Batch: 75/371	 Error: 0.442	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 100/371	 Error: 0.357	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 125/371	 Error: 0.599	 Accuracy: 0.81
# Epoch: 43/50	 Batch: 150/371	 Error: 0.798	 Accuracy: 0.69
# Epoch: 43/50	 Batch: 175/371	 Error: 0.459	 Accuracy: 0.84
# Epoch: 43/50	 Batch: 200/371	 Error: 0.977	 Accuracy: 0.69
# Epoch: 43/50	 Batch: 225/371	 Error: 0.670	 Accuracy: 0.81
# Epoch: 43/50	 Batch: 250/371	 Error: 0.377	 Accuracy: 0.84
# Epoch: 43/50	 Batch: 275/371	 Error: 0.581	 Accuracy: 0.84
# Epoch: 43/50	 Batch: 300/371	 Error: 0.610	 Accuracy: 0.81
# Epoch: 43/50	 Batch: 325/371	 Error: 0.349	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 350/371	 Error: 0.406	 Accuracy: 0.88
#
#
# 	 Epoch: 43
# 	 Validation loss: 0.62
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 585.4
#
#
# Epoch: 44/50	 Batch: 25/371	 Error: 0.450	 Accuracy: 0.84
# Epoch: 44/50	 Batch: 50/371	 Error: 0.702	 Accuracy: 0.75
# Epoch: 44/50	 Batch: 75/371	 Error: 0.468	 Accuracy: 0.81
# Epoch: 44/50	 Batch: 100/371	 Error: 0.577	 Accuracy: 0.81
# Epoch: 44/50	 Batch: 125/371	 Error: 0.642	 Accuracy: 0.75
# Epoch: 44/50	 Batch: 150/371	 Error: 0.485	 Accuracy: 0.84
# Epoch: 44/50	 Batch: 175/371	 Error: 0.385	 Accuracy: 0.84
# Epoch: 44/50	 Batch: 200/371	 Error: 0.309	 Accuracy: 0.94
# Epoch: 44/50	 Batch: 225/371	 Error: 0.322	 Accuracy: 0.91
# Epoch: 44/50	 Batch: 250/371	 Error: 0.590	 Accuracy: 0.81
# Epoch: 44/50	 Batch: 275/371	 Error: 0.610	 Accuracy: 0.88
# Epoch: 44/50	 Batch: 300/371	 Error: 0.577	 Accuracy: 0.84
# Epoch: 44/50	 Batch: 325/371	 Error: 0.711	 Accuracy: 0.66
# Epoch: 44/50	 Batch: 350/371	 Error: 0.679	 Accuracy: 0.78
#
#
# 	 Epoch: 44
# 	 Validation loss: 0.60
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 599.3
#
#
# Epoch: 45/50	 Batch: 25/371	 Error: 0.565	 Accuracy: 0.81
# Epoch: 45/50	 Batch: 50/371	 Error: 0.589	 Accuracy: 0.72
# Epoch: 45/50	 Batch: 75/371	 Error: 0.415	 Accuracy: 0.88
# Epoch: 45/50	 Batch: 100/371	 Error: 0.469	 Accuracy: 0.84
# Epoch: 45/50	 Batch: 125/371	 Error: 0.491	 Accuracy: 0.81
# Epoch: 45/50	 Batch: 150/371	 Error: 0.303	 Accuracy: 0.91
# Epoch: 45/50	 Batch: 175/371	 Error: 0.399	 Accuracy: 0.81
# Epoch: 45/50	 Batch: 200/371	 Error: 0.884	 Accuracy: 0.69
# Epoch: 45/50	 Batch: 225/371	 Error: 0.480	 Accuracy: 0.78
# Epoch: 45/50	 Batch: 250/371	 Error: 0.728	 Accuracy: 0.72
# Epoch: 45/50	 Batch: 275/371	 Error: 0.374	 Accuracy: 0.91
# Epoch: 45/50	 Batch: 300/371	 Error: 0.614	 Accuracy: 0.75
# Epoch: 45/50	 Batch: 325/371	 Error: 0.554	 Accuracy: 0.75
# Epoch: 45/50	 Batch: 350/371	 Error: 1.097	 Accuracy: 0.66
#
#
# 	 Epoch: 45
# 	 Validation loss: 0.61
# 	 Validation accuracy: 0.82
# 	 Elapsed time: 613.5
#
#
# Epoch: 46/50	 Batch: 25/371	 Error: 0.537	 Accuracy: 0.81
# Epoch: 46/50	 Batch: 50/371	 Error: 0.547	 Accuracy: 0.84
# Epoch: 46/50	 Batch: 75/371	 Error: 0.871	 Accuracy: 0.75
# Epoch: 46/50	 Batch: 100/371	 Error: 0.338	 Accuracy: 0.91
# Epoch: 46/50	 Batch: 125/371	 Error: 0.587	 Accuracy: 0.84
# Epoch: 46/50	 Batch: 150/371	 Error: 0.429	 Accuracy: 0.84
# Epoch: 46/50	 Batch: 175/371	 Error: 0.541	 Accuracy: 0.75
# Epoch: 46/50	 Batch: 200/371	 Error: 0.349	 Accuracy: 0.88
# Epoch: 46/50	 Batch: 225/371	 Error: 0.362	 Accuracy: 0.81
# Epoch: 46/50	 Batch: 250/371	 Error: 0.582	 Accuracy: 0.78
# Epoch: 46/50	 Batch: 275/371	 Error: 0.511	 Accuracy: 0.78
# Epoch: 46/50	 Batch: 300/371	 Error: 0.631	 Accuracy: 0.84
# Epoch: 46/50	 Batch: 325/371	 Error: 0.392	 Accuracy: 0.81
# Epoch: 46/50	 Batch: 350/371	 Error: 0.417	 Accuracy: 0.91
#
#
# 	 Epoch: 46
# 	 Validation loss: 0.62
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 629.9
#
#
# Epoch: 47/50	 Batch: 25/371	 Error: 0.461	 Accuracy: 0.84
# Epoch: 47/50	 Batch: 50/371	 Error: 0.325	 Accuracy: 0.88
# Epoch: 47/50	 Batch: 75/371	 Error: 0.406	 Accuracy: 0.78
# Epoch: 47/50	 Batch: 100/371	 Error: 0.478	 Accuracy: 0.84
# Epoch: 47/50	 Batch: 125/371	 Error: 0.780	 Accuracy: 0.75
# Epoch: 47/50	 Batch: 150/371	 Error: 0.821	 Accuracy: 0.78
# Epoch: 47/50	 Batch: 175/371	 Error: 0.625	 Accuracy: 0.81
# Epoch: 47/50	 Batch: 200/371	 Error: 0.641	 Accuracy: 0.78
# Epoch: 47/50	 Batch: 225/371	 Error: 0.759	 Accuracy: 0.69
# Epoch: 47/50	 Batch: 250/371	 Error: 0.340	 Accuracy: 0.91
# Epoch: 47/50	 Batch: 275/371	 Error: 0.676	 Accuracy: 0.78
# Epoch: 47/50	 Batch: 300/371	 Error: 0.649	 Accuracy: 0.75
# Epoch: 47/50	 Batch: 325/371	 Error: 0.496	 Accuracy: 0.88
# Epoch: 47/50	 Batch: 350/371	 Error: 0.462	 Accuracy: 0.84
#
#
# 	 Epoch: 47
# 	 Validation loss: 0.61
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 643.7
#
#
# Epoch: 48/50	 Batch: 25/371	 Error: 0.556	 Accuracy: 0.72
# Epoch: 48/50	 Batch: 50/371	 Error: 1.092	 Accuracy: 0.62
# Epoch: 48/50	 Batch: 75/371	 Error: 0.771	 Accuracy: 0.72
# Epoch: 48/50	 Batch: 100/371	 Error: 0.569	 Accuracy: 0.81
# Epoch: 48/50	 Batch: 125/371	 Error: 0.448	 Accuracy: 0.84
# Epoch: 48/50	 Batch: 150/371	 Error: 0.423	 Accuracy: 0.88
# Epoch: 48/50	 Batch: 175/371	 Error: 0.538	 Accuracy: 0.78
# Epoch: 48/50	 Batch: 200/371	 Error: 0.697	 Accuracy: 0.72
# Epoch: 48/50	 Batch: 225/371	 Error: 0.795	 Accuracy: 0.78
# Epoch: 48/50	 Batch: 250/371	 Error: 0.583	 Accuracy: 0.88
# Epoch: 48/50	 Batch: 275/371	 Error: 0.530	 Accuracy: 0.84
# Epoch: 48/50	 Batch: 300/371	 Error: 0.711	 Accuracy: 0.81
# Epoch: 48/50	 Batch: 325/371	 Error: 0.560	 Accuracy: 0.84
# Epoch: 48/50	 Batch: 350/371	 Error: 0.241	 Accuracy: 0.91
#
#
# 	 Epoch: 48
# 	 Validation loss: 0.63
# 	 Validation accuracy: 0.82
# 	 Elapsed time: 657.8
#
#
# Epoch: 49/50	 Batch: 25/371	 Error: 0.734	 Accuracy: 0.72
# Epoch: 49/50	 Batch: 50/371	 Error: 0.235	 Accuracy: 0.94
# Epoch: 49/50	 Batch: 75/371	 Error: 0.497	 Accuracy: 0.81
# Epoch: 49/50	 Batch: 100/371	 Error: 0.423	 Accuracy: 0.81
# Epoch: 49/50	 Batch: 125/371	 Error: 0.496	 Accuracy: 0.84
# Epoch: 49/50	 Batch: 150/371	 Error: 0.708	 Accuracy: 0.75
# Epoch: 49/50	 Batch: 175/371	 Error: 0.455	 Accuracy: 0.91
# Epoch: 49/50	 Batch: 200/371	 Error: 0.923	 Accuracy: 0.66
# Epoch: 49/50	 Batch: 225/371	 Error: 0.457	 Accuracy: 0.81
# Epoch: 49/50	 Batch: 250/371	 Error: 0.612	 Accuracy: 0.81
# Epoch: 49/50	 Batch: 275/371	 Error: 0.678	 Accuracy: 0.75
# Epoch: 49/50	 Batch: 300/371	 Error: 0.373	 Accuracy: 0.88
# Epoch: 49/50	 Batch: 325/371	 Error: 0.658	 Accuracy: 0.75
# Epoch: 49/50	 Batch: 350/371	 Error: 0.752	 Accuracy: 0.72
#
#
# 	 Epoch: 49
# 	 Validation loss: 0.61
# 	 Validation accuracy: 0.81
# 	 Elapsed time: 671.6
#
#
# Epoch: 50/50	 Batch: 25/371	 Error: 0.478	 Accuracy: 0.91
# Epoch: 50/50	 Batch: 50/371	 Error: 0.324	 Accuracy: 0.91
# Epoch: 50/50	 Batch: 75/371	 Error: 0.532	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 100/371	 Error: 0.551	 Accuracy: 0.78
# Epoch: 50/50	 Batch: 125/371	 Error: 0.736	 Accuracy: 0.69
# Epoch: 50/50	 Batch: 150/371	 Error: 0.519	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 175/371	 Error: 0.740	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 200/371	 Error: 0.513	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 225/371	 Error: 0.640	 Accuracy: 0.69
# Epoch: 50/50	 Batch: 250/371	 Error: 0.506	 Accuracy: 0.78
# Epoch: 50/50	 Batch: 275/371	 Error: 0.299	 Accuracy: 0.91
# Epoch: 50/50	 Batch: 300/371	 Error: 0.622	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 325/371	 Error: 0.599	 Accuracy: 0.78
# Epoch: 50/50	 Batch: 350/371	 Error: 0.868	 Accuracy: 0.75
#
#
# 	 Epoch: 50
# 	 Validation loss: 0.62
# 	 Validation accuracy: 0.82
# 	 Elapsed time: 685.3

# %%
fname = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/eval_preds_{}.p'.format(WHICH_TARGET)
with open(fname, 'wb') as f:
    pickle.dump(eval_preds, f)

# %%
plot_tracks(
    train_track['error'],
    train_track['accuracy'],
    eval_errors = eval_track['error'],
    eval_accuracies = eval_track['accuracy'],
    file_name = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/tracks_{}.png'.format(WHICH_TARGET)
)

# %%
tester = ecnumTester(trainer.model, test_dataset)
err, acc = tester.test()
print('Test accuracy: {:1.2f}'.format(acc))
# Out:
# Test accuracy: 0.80

# %%
report = tester.get_report()
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81       782
#            1       0.85      0.84      0.85       437
#            2       0.82      0.76      0.79       398
#            3       0.79      0.79      0.79       391
#            4       0.89      0.70      0.78       258
#            5       0.84      0.73      0.78       251
#            6       0.80      0.83      0.82       485
#            7       0.71      0.81      0.76        68
#            8       0.00      0.00      0.00         3
#            9       0.75      0.38      0.50         8
#           10       0.97      0.92      0.95        39
#           11       1.00      0.67      0.80         3
#           12       0.62      0.68      0.65        22
#           13       0.88      0.82      0.85        80
#           14       0.92      1.00      0.96        12
#           15       0.92      0.69      0.79        16
#           16       0.90      0.53      0.67        17
#           17       0.50      0.33      0.40         9
#           18       0.00      0.00      0.00         1
#           19       1.00      0.50      0.67         2
#           20       0.00      0.00      0.00         2
#           21       0.00      0.00      0.00         1
#           22       1.00      0.50      0.67         2
#           23       0.00      0.00      0.00         4
#
#     accuracy                           0.80      3291
#    macro avg       0.66      0.56      0.59      3291
# weighted avg       0.81      0.80      0.80      3291
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = tester.get_confmat()
plot_confmat(
    cm, 
    file_name = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/confmat_{}.png'.format(WHICH_TARGET),
    include_values = False
)

# %%
fpr, tpr, auroc = tester.get_roc()
plot_rocs(
    fpr, 
    tpr, 
    auroc, 
    show_legend = False,
    file_name = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/rocs_{}.png'.format(WHICH_TARGET)
)

# %% [markdown]
# ---
