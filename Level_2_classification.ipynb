# %% [markdown]
# <br>
#
# ## Imports

# %%
import time
import pickle
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torch.optim import Adam

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_curve, auc, classification_report

# %% [markdown]
# <br>
#
# Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <br>
#
# ## Define constants

# %%
TEST_SIZE = .2
EVAL_SIZE = .1
RANDOM_SEED = 30
WHICH_TARGET = 'Level_1'

# %% [markdown]
# <br>
#
# ## Define classes

# %%
class seqembData(Dataset):
    def __init__(self, inputs, labels):
        for input in inputs:
            assert input.shape[0] == len(labels)
        
        self.n = len(labels)
        self.labels = torch.as_tensor(labels)
        self.inputs = [torch.as_tensor(input).float() for input in inputs]

    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        return [input[idx] for input in self.inputs], self.labels[idx]

# %%
class ecnumClassifier(nn.Module):
    def __init__(self, input_sizes, num_classes, hidden_size = 256, linear_sizes = [64, 64], drop_prob = .2):
        super().__init__()

        # Input processing layers
        proc_layers = []
        for size in input_sizes:
            proc_layer = nn.Sequential(
                nn.Dropout(p = drop_prob),
                nn.Linear(size, hidden_size),
                nn.ReLU(),
                nn.BatchNorm1d(hidden_size)
            )
            proc_layers.append(proc_layer)
        self.proc_layers = nn.ModuleList(proc_layers)

        # Linear layers
        input_size = hidden_size * len(input_sizes)
        linear_layers = []
        for output_size in linear_sizes:
            linear_layers.append(nn.Dropout(p = drop_prob))
            linear_layers.append(nn.Linear(input_size, output_size))
            linear_layers.append(nn.ReLU())
            linear_layers.append(nn.BatchNorm1d(output_size))
            input_size = output_size
        self.linear_layers = nn.Sequential(*linear_layers)

        # Output layer        
        self.output_layer = nn.Linear(input_size, num_classes)
    
    def forward(self, x_list):
        # Process inputs by independent processign layers
        y_list = []
        for i, proc_layer in enumerate(self.proc_layers):
            y_list.append(proc_layer(x_list[i]))

        # Concat together            
        y = torch.cat(y_list, dim = 1)

        # Pass through linear layers
        z = self.linear_layers(y)

        # Get output
        o = self.output_layer(z)

        return o

# %% [markdown]
# <br>
#
#
# Aux. functions

# %%
def get_preds(logits):
    proba = torch.log_softmax(logits, dim = 1)
    _, preds = torch.max(proba, dim = 1)
    return proba, preds

def calc_acc(preds, targets):
    return torch.sum(preds == targets) / len(targets)

# %%
class ecnumTrainer():
    def __init__(self, model, train_data, eval_data = None, batch_size = 32, learning_rate = 1e-4, decay = 1e-5, device = 'cpu'):

        # Set device
        self.device = device

        # Set model
        self.model = model
        
        # Set train data loader
        self.train_loader = DataLoader(
            train_data,
            batch_size = batch_size,
            shuffle = True
        )

        # Set optimizer
        self.optimizer = Adam(
            self.model.parameters(),
            lr = learning_rate,
            weight_decay = decay
        )

        # Set eval data loader
        if eval_data is not None:
            self.eval_loader = DataLoader(
                eval_data, 
                batch_size=len(eval_data),
                shuffle = False
            )
        else:
            self.eval_loader = None

        # Set loss function
        self.loss_func = nn.CrossEntropyLoss() 

    def validate(self):
        self.model.eval()
        with torch.no_grad():
            inputs, targets = next(iter(self.eval_loader))
            inputs = [input.to(self.device) for input in inputs]
            logits = self.model(inputs)

            # Calc error
            error = self.loss_func(logits, targets)
            error = error.item()

        return logits, targets, error

    def train(self, num_epochs = 20, verbosity = 10):

        # Train track container
        train_track = {'error' : [], 'accuracy' : []}
        if self.eval_loader is not None:
            eval_track = {'error' : [], 'accuracy' : []}
            eval_preds = {}
        else:
            eval_track = None
            eval_preds = None

        # Set device
        self.model.to(self.device)
        
        # Training
        n = len(self.train_loader)
        start = time.time()
        for epoch in range(num_epochs):
            self.model.train()
            train_error = 0.    
            train_acc = 0.        
            for i, (inputs, targets) in enumerate(self.train_loader):
                inputs = [input.to(self.device) for input in inputs]
                logits = self.model(inputs)

                # Calc error and do training step
                error = self.loss_func(logits, targets)
                self.optimizer.zero_grad()
                error.backward()
                self.optimizer.step()
                error = error.item()

                # Get predictions
                _, preds = get_preds(logits)

                # Calculate accuracy
                acc = calc_acc(preds, targets)
                acc = acc.item()

                # Report
                if verbosity > 0:
                    if (i + 1) % verbosity == 0:
                        print('Epoch: {}/{}\t Batch: {}/{}\t Error: {:1.3f}\t Accuracy: {:1.2f}'.format(epoch + 1, num_epochs, i + 1, n, error, acc))

                # Increment training error and accuracy              
                train_error += error                
                train_acc += acc

            # Average training error
            train_error /= n      
            train_track['error'].append(train_error)

            # Average training accuracy
            train_acc /= n
            train_track['accuracy'].append(train_acc)

            # Validation
            if self.eval_loader is not None:
                logits, targets, error = self.validate()

                # Get predictions
                _, preds = get_preds(logits)

                # Assess accuracy
                acc = calc_acc(preds, targets)
                acc = acc.item()

                # Add to eval track
                eval_track['error'].append(error)
                eval_track['accuracy'].append(acc)

                # Add to eval preds
                eval_preds['epoch_{}'.format(epoch + 1)] = {
                    'preds' : preds.cpu().numpy(),
                    'targets' : targets.cpu().numpy()
                }

                print('\n')
                print('\t Epoch: {}'.format(epoch + 1))
                print('\t Validation loss: {:1.2f}'.format(error))
                print('\t Validation accuracy: {:1.2f}'.format(acc))
                print('\t Elapsed time: {:1.1f}'.format(time.time()-start))
                print('\n')

        return train_track, eval_track, eval_preds

# %%
class ecnumTester():
    def __init__(self, model, test_data, device = 'cpu'):

        # Set device
        self.device = device

        # Set model
        self.model = model
        
        # Set test data loader
        self.test_loader = DataLoader(
            test_data, 
            batch_size=len(test_data),
            shuffle = False
        )

        # Set loss function
        self.loss_func = nn.CrossEntropyLoss() 

    def test(self):
        self.model.eval()
        with torch.no_grad():
            inputs, targets = next(iter(self.test_loader))
            inputs = [input.to(self.device) for input in inputs]
            logits = self.model(inputs)

            # Calc error
            error = self.loss_func(logits, targets)
            error = error.item()

            # Get predictions
            proba, preds = get_preds(logits)

            # Assess accuracy
            acc = calc_acc(preds, targets)
            acc = acc.item()

        # Store targets
        self.targets = targets.cpu().numpy()
        self.proba = proba.cpu().numpy()
        self.preds = preds.cpu().numpy()
 
        return error, acc

    def get_report(self):            
        labels = list(range(self.proba.shape[1]))
        return classification_report(self.targets, self.preds, labels=labels)

    def get_confmat(self):
        labels = list(range(self.proba.shape[1]))
        conf_mat = confusion_matrix(
            self.targets, 
            self.preds,
            labels = labels
        )
        return conf_mat

    def get_roc(self):
        fpr = {}
        tpr = {}
        auroc = {}
        for i in range(self.proba.shape[1]):
            fpr[i], tpr[i], _ = roc_curve(self.targets, self.proba[:,i], pos_label = i)
            auroc[i] = auc(fpr[i], tpr[i])
        return fpr, tpr, auroc

# %%
def plot_confmat(cm, title = None, file_name = None):
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    
    if title is not None:
        disp.ax_.set_title(title)

    if file_name is None:
        plt.show()
    else:
        plt.savefig(file_name, dpi = 100)

# %%
def plot_tracks(errors, accuracies, eval_errors = None, eval_accuracies = None, title = None, file_name = None):
    # Prepare x-values
    x = np.arange(len(errors)) + 1.
    
    # Prepare plot
    fig, ax1 = plt.subplots()
    ax1.set_xlabel('Epochs [#]')
    ax1.minorticks_on()
    ax1.grid()
    
    # Plot errors
    color = 'maroon'
    ax1.plot(x, errors, color=color)    
    ax1.set_ylabel('Cross-Entropy Loss', color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    # Plot evaluation errors
    if eval_errors:
        ax1.plot(x, eval_errors, color=color, linestyle='dashed')    

    # Plot performance
    color = 'steelblue'
    ax2 = ax1.twinx()
    ax2.plot(x, accuracies, color=color)
    ax2.set_ylabel('Accuracy', color=color)
    ax2.tick_params(axis='y', labelcolor=color)    
    # Plot evaluation accuracies
    if eval_accuracies :
        ax2.plot(x, eval_accuracies, color=color, linestyle='dashed')


    # Add title
    if title is not None:
        plt.suptitle(title)

    # Plot
    fig.tight_layout() 
    if file_name is None:
        plt.show()
    else:
        plt.savefig(file_name, dpi = 100)

# %%
def plot_rocs(fpr, tpr, auroc, title = None, file_name = None):
    plt.figure()
    lw = 1
    classes = fpr.keys()
    for c in classes:                        
        plt.plot(
            fpr[c], tpr[c], 
            # color='darkorange',
            lw=lw, 
            label='Class: {}; AUROC = {:1.2f}'.format(c, auroc[c])
        )
        plt.plot([0, 1], [0, 1], color='black', lw=lw, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
    plt.legend(loc="lower right")
    plt.grid()

    if title is not None:
        plt.title(title)

    if file_name is None:
        plt.show()
    else:
        plt.savefig(file_name, dpi = 100)

# %% [markdown]
# <br>
#
# ## Load data and create datasets (train, eval, test)

# %%
path = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/embeddings/esm_embeddings.p'
with open(path, 'rb') as f:
    esm_embedding_output = pickle.load(f)

# %%
path = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/embeddings/ProtAlbert_embeddings.p'
with open(path, 'rb') as f:
    protalbert_embedding_output = pickle.load(f)

# %%
path = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/embeddings/TAPE_embeddings.p'
with open(path, 'rb') as f:
    tape_embedding_output = pickle.load(f)

# %% [markdown]
# <br>
#
# Assert data integrity

# %%
assert esm_embedding_output['seq_data'].shape == protalbert_embedding_output['seq_data'].shape

# %%
assert tape_embedding_output['seq_data'].shape == protalbert_embedding_output['seq_data'].shape

# %% [markdown]
# <br>
#
# Select labels and inputs

# %%
labels = esm_embedding_output['seq_data'][WHICH_TARGET].values
inputs = [
    esm_embedding_output['seq_embeddings'],         # Embeddings from esm
    protalbert_embedding_output['seq_embeddings'],  # Embeddings from protAlbert
    tape_embedding_output['seq_embeddings']         # Embeddings from TAPE
]

# %% [markdown]
# <br>
#
# Sanitize against nans

# %%
nonan_idx = np.where(~np.isnan(labels))[0]
labels = labels[nonan_idx]
inputs = [input[nonan_idx] for input in inputs]

# %% [markdown]
# <br>
#
# Encode labels

# %%
ec_encoder = LabelEncoder()
labels = ec_encoder.fit_transform(np.array(labels))

# %% [markdown]
# <br>
#
# Train test split

# %%
train_idx, test_idx = train_test_split(
    range(len(labels)), 
    test_size=TEST_SIZE, 
    random_state=RANDOM_SEED
)

train_idx, eval_idx = train_test_split(
    train_idx, 
    test_size=EVAL_SIZE,
    random_state = RANDOM_SEED
)

# %% [markdown]
# <br>
#
# Create datasets

# %%
# Train data
train_labels = labels[train_idx]
train_inputs = [input[train_idx] for input in inputs]
train_dataset = seqembData(train_inputs, train_labels)

# Eval data
eval_labels = labels[eval_idx]
eval_inputs = [input[eval_idx] for input in inputs]
eval_dataset = seqembData(eval_inputs, eval_labels)

# Test data
test_labels = labels[test_idx]
test_inputs = [input[test_idx] for input in inputs]
test_dataset = seqembData(test_inputs, test_labels)

# %% [markdown]
# <br>
#
# ## Train the model

# %% [markdown]
# <br>
#
# Init model

# %%
input_sizes = [input.shape[1] for input in train_inputs]
num_classes = len(ec_encoder.classes_)
model = ecnumClassifier(
    input_sizes = input_sizes, 
    num_classes = num_classes,
    hidden_size = 256,
    linear_sizes = [512, 512, 64],
    drop_prob = .4
)

# %%
model = model.float()

# %% [markdown]
# <br>
#
# Select device

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# <br>
#
# Init trainer

# %%
trainer = ecnumTrainer(
    model,
    train_dataset,
    eval_dataset,
    batch_size = 32,
    learning_rate = 1e-4,
    device = device,
)

# %%
train_track, eval_track, eval_preds = trainer.train(num_epochs = 50, verbosity = 25)
# Out:
# Epoch: 1/50	 Batch: 25/375	 Error: 2.123	 Accuracy: 0.12
# Epoch: 1/50	 Batch: 50/375	 Error: 2.003	 Accuracy: 0.16
# Epoch: 1/50	 Batch: 75/375	 Error: 2.024	 Accuracy: 0.16
# Epoch: 1/50	 Batch: 100/375	 Error: 1.966	 Accuracy: 0.22
# Epoch: 1/50	 Batch: 125/375	 Error: 1.923	 Accuracy: 0.28
# Epoch: 1/50	 Batch: 150/375	 Error: 1.778	 Accuracy: 0.38
# Epoch: 1/50	 Batch: 175/375	 Error: 1.783	 Accuracy: 0.31
# Epoch: 1/50	 Batch: 200/375	 Error: 2.034	 Accuracy: 0.22
# Epoch: 1/50	 Batch: 225/375	 Error: 1.884	 Accuracy: 0.31
# Epoch: 1/50	 Batch: 250/375	 Error: 1.542	 Accuracy: 0.50
# Epoch: 1/50	 Batch: 275/375	 Error: 1.618	 Accuracy: 0.41
# Epoch: 1/50	 Batch: 300/375	 Error: 1.480	 Accuracy: 0.41
# Epoch: 1/50	 Batch: 325/375	 Error: 1.727	 Accuracy: 0.31
# Epoch: 1/50	 Batch: 350/375	 Error: 1.527	 Accuracy: 0.47
# Epoch: 1/50	 Batch: 375/375	 Error: 1.631	 Accuracy: 0.41
#
#
# 	 Epoch: 1
# 	 Validation loss: 1.55
# 	 Validation accuracy: 0.46
# 	 Elapsed time: 16.8
#
#
# Epoch: 2/50	 Batch: 25/375	 Error: 1.422	 Accuracy: 0.62
# Epoch: 2/50	 Batch: 50/375	 Error: 1.457	 Accuracy: 0.53
# Epoch: 2/50	 Batch: 75/375	 Error: 1.614	 Accuracy: 0.50
# Epoch: 2/50	 Batch: 100/375	 Error: 1.474	 Accuracy: 0.50
# Epoch: 2/50	 Batch: 125/375	 Error: 1.458	 Accuracy: 0.50
# Epoch: 2/50	 Batch: 150/375	 Error: 1.585	 Accuracy: 0.59
# Epoch: 2/50	 Batch: 175/375	 Error: 1.323	 Accuracy: 0.66
# Epoch: 2/50	 Batch: 200/375	 Error: 1.330	 Accuracy: 0.56
# Epoch: 2/50	 Batch: 225/375	 Error: 1.578	 Accuracy: 0.47
# Epoch: 2/50	 Batch: 250/375	 Error: 1.627	 Accuracy: 0.53
# Epoch: 2/50	 Batch: 275/375	 Error: 1.464	 Accuracy: 0.44
# Epoch: 2/50	 Batch: 300/375	 Error: 1.348	 Accuracy: 0.59
# Epoch: 2/50	 Batch: 325/375	 Error: 1.108	 Accuracy: 0.59
# Epoch: 2/50	 Batch: 350/375	 Error: 1.266	 Accuracy: 0.62
# Epoch: 2/50	 Batch: 375/375	 Error: 1.146	 Accuracy: 0.63
#
#
# 	 Epoch: 2
# 	 Validation loss: 1.18
# 	 Validation accuracy: 0.64
# 	 Elapsed time: 29.6
#
#
# Epoch: 3/50	 Batch: 25/375	 Error: 0.854	 Accuracy: 0.78
# Epoch: 3/50	 Batch: 50/375	 Error: 1.281	 Accuracy: 0.50
# Epoch: 3/50	 Batch: 75/375	 Error: 1.124	 Accuracy: 0.69
# Epoch: 3/50	 Batch: 100/375	 Error: 0.885	 Accuracy: 0.75
# Epoch: 3/50	 Batch: 125/375	 Error: 0.920	 Accuracy: 0.78
# Epoch: 3/50	 Batch: 150/375	 Error: 1.613	 Accuracy: 0.47
# Epoch: 3/50	 Batch: 175/375	 Error: 1.277	 Accuracy: 0.56
# Epoch: 3/50	 Batch: 200/375	 Error: 1.301	 Accuracy: 0.59
# Epoch: 3/50	 Batch: 225/375	 Error: 1.220	 Accuracy: 0.59
# Epoch: 3/50	 Batch: 250/375	 Error: 0.970	 Accuracy: 0.66
# Epoch: 3/50	 Batch: 275/375	 Error: 1.209	 Accuracy: 0.53
# Epoch: 3/50	 Batch: 300/375	 Error: 1.043	 Accuracy: 0.59
# Epoch: 3/50	 Batch: 325/375	 Error: 1.328	 Accuracy: 0.62
# Epoch: 3/50	 Batch: 350/375	 Error: 1.027	 Accuracy: 0.72
# Epoch: 3/50	 Batch: 375/375	 Error: 0.935	 Accuracy: 0.70
#
#
# 	 Epoch: 3
# 	 Validation loss: 0.94
# 	 Validation accuracy: 0.72
# 	 Elapsed time: 44.0
#
#
# Epoch: 4/50	 Batch: 25/375	 Error: 1.153	 Accuracy: 0.59
# Epoch: 4/50	 Batch: 50/375	 Error: 0.961	 Accuracy: 0.75
# Epoch: 4/50	 Batch: 75/375	 Error: 0.956	 Accuracy: 0.72
# Epoch: 4/50	 Batch: 100/375	 Error: 1.321	 Accuracy: 0.50
# Epoch: 4/50	 Batch: 125/375	 Error: 0.907	 Accuracy: 0.66
# Epoch: 4/50	 Batch: 150/375	 Error: 1.334	 Accuracy: 0.47
# Epoch: 4/50	 Batch: 175/375	 Error: 1.223	 Accuracy: 0.62
# Epoch: 4/50	 Batch: 200/375	 Error: 0.836	 Accuracy: 0.72
# Epoch: 4/50	 Batch: 225/375	 Error: 1.046	 Accuracy: 0.59
# Epoch: 4/50	 Batch: 250/375	 Error: 0.955	 Accuracy: 0.69
# Epoch: 4/50	 Batch: 275/375	 Error: 1.100	 Accuracy: 0.66
# Epoch: 4/50	 Batch: 300/375	 Error: 1.003	 Accuracy: 0.66
# Epoch: 4/50	 Batch: 325/375	 Error: 1.047	 Accuracy: 0.75
# Epoch: 4/50	 Batch: 350/375	 Error: 0.866	 Accuracy: 0.72
# Epoch: 4/50	 Batch: 375/375	 Error: 0.831	 Accuracy: 0.74
#
#
# 	 Epoch: 4
# 	 Validation loss: 0.84
# 	 Validation accuracy: 0.75
# 	 Elapsed time: 58.2
#
#
# Epoch: 5/50	 Batch: 25/375	 Error: 0.729	 Accuracy: 0.81
# Epoch: 5/50	 Batch: 50/375	 Error: 1.006	 Accuracy: 0.69
# Epoch: 5/50	 Batch: 75/375	 Error: 0.765	 Accuracy: 0.78
# Epoch: 5/50	 Batch: 100/375	 Error: 0.899	 Accuracy: 0.59
# Epoch: 5/50	 Batch: 125/375	 Error: 0.693	 Accuracy: 0.84
# Epoch: 5/50	 Batch: 150/375	 Error: 1.434	 Accuracy: 0.59
# Epoch: 5/50	 Batch: 175/375	 Error: 0.769	 Accuracy: 0.72
# Epoch: 5/50	 Batch: 200/375	 Error: 0.860	 Accuracy: 0.72
# Epoch: 5/50	 Batch: 225/375	 Error: 0.802	 Accuracy: 0.78
# Epoch: 5/50	 Batch: 250/375	 Error: 1.349	 Accuracy: 0.59
# Epoch: 5/50	 Batch: 275/375	 Error: 0.782	 Accuracy: 0.75
# Epoch: 5/50	 Batch: 300/375	 Error: 0.723	 Accuracy: 0.75
# Epoch: 5/50	 Batch: 325/375	 Error: 1.273	 Accuracy: 0.59
# Epoch: 5/50	 Batch: 350/375	 Error: 1.080	 Accuracy: 0.62
# Epoch: 5/50	 Batch: 375/375	 Error: 1.058	 Accuracy: 0.56
#
#
# 	 Epoch: 5
# 	 Validation loss: 0.76
# 	 Validation accuracy: 0.77
# 	 Elapsed time: 73.5
#
#
# Epoch: 6/50	 Batch: 25/375	 Error: 0.930	 Accuracy: 0.69
# Epoch: 6/50	 Batch: 50/375	 Error: 0.555	 Accuracy: 0.88
# Epoch: 6/50	 Batch: 75/375	 Error: 1.150	 Accuracy: 0.59
# Epoch: 6/50	 Batch: 100/375	 Error: 1.135	 Accuracy: 0.66
# Epoch: 6/50	 Batch: 125/375	 Error: 0.924	 Accuracy: 0.75
# Epoch: 6/50	 Batch: 150/375	 Error: 1.107	 Accuracy: 0.62
# Epoch: 6/50	 Batch: 175/375	 Error: 0.536	 Accuracy: 0.91
# Epoch: 6/50	 Batch: 200/375	 Error: 0.917	 Accuracy: 0.66
# Epoch: 6/50	 Batch: 225/375	 Error: 0.612	 Accuracy: 0.91
# Epoch: 6/50	 Batch: 250/375	 Error: 0.854	 Accuracy: 0.72
# Epoch: 6/50	 Batch: 275/375	 Error: 1.213	 Accuracy: 0.62
# Epoch: 6/50	 Batch: 300/375	 Error: 0.897	 Accuracy: 0.59
# Epoch: 6/50	 Batch: 325/375	 Error: 0.950	 Accuracy: 0.66
# Epoch: 6/50	 Batch: 350/375	 Error: 0.730	 Accuracy: 0.88
# Epoch: 6/50	 Batch: 375/375	 Error: 1.102	 Accuracy: 0.67
#
#
# 	 Epoch: 6
# 	 Validation loss: 0.69
# 	 Validation accuracy: 0.78
# 	 Elapsed time: 87.9
#
#
# Epoch: 7/50	 Batch: 25/375	 Error: 1.063	 Accuracy: 0.66
# Epoch: 7/50	 Batch: 50/375	 Error: 1.028	 Accuracy: 0.69
# Epoch: 7/50	 Batch: 75/375	 Error: 1.229	 Accuracy: 0.62
# Epoch: 7/50	 Batch: 100/375	 Error: 1.010	 Accuracy: 0.69
# Epoch: 7/50	 Batch: 125/375	 Error: 0.967	 Accuracy: 0.66
# Epoch: 7/50	 Batch: 150/375	 Error: 0.512	 Accuracy: 0.88
# Epoch: 7/50	 Batch: 175/375	 Error: 0.661	 Accuracy: 0.75
# Epoch: 7/50	 Batch: 200/375	 Error: 0.679	 Accuracy: 0.72
# Epoch: 7/50	 Batch: 225/375	 Error: 1.206	 Accuracy: 0.53
# Epoch: 7/50	 Batch: 250/375	 Error: 0.763	 Accuracy: 0.75
# Epoch: 7/50	 Batch: 275/375	 Error: 0.620	 Accuracy: 0.78
# Epoch: 7/50	 Batch: 300/375	 Error: 0.797	 Accuracy: 0.81
# Epoch: 7/50	 Batch: 325/375	 Error: 0.779	 Accuracy: 0.69
# Epoch: 7/50	 Batch: 350/375	 Error: 0.784	 Accuracy: 0.69
# Epoch: 7/50	 Batch: 375/375	 Error: 0.761	 Accuracy: 0.78
#
#
# 	 Epoch: 7
# 	 Validation loss: 0.65
# 	 Validation accuracy: 0.80
# 	 Elapsed time: 102.6
#
#
# Epoch: 8/50	 Batch: 25/375	 Error: 0.625	 Accuracy: 0.72
# Epoch: 8/50	 Batch: 50/375	 Error: 0.772	 Accuracy: 0.75
# Epoch: 8/50	 Batch: 75/375	 Error: 0.477	 Accuracy: 0.84
# Epoch: 8/50	 Batch: 100/375	 Error: 0.762	 Accuracy: 0.69
# Epoch: 8/50	 Batch: 125/375	 Error: 0.992	 Accuracy: 0.59
# Epoch: 8/50	 Batch: 150/375	 Error: 0.929	 Accuracy: 0.72
# Epoch: 8/50	 Batch: 175/375	 Error: 0.801	 Accuracy: 0.75
# Epoch: 8/50	 Batch: 200/375	 Error: 0.988	 Accuracy: 0.69
# Epoch: 8/50	 Batch: 225/375	 Error: 0.806	 Accuracy: 0.69
# Epoch: 8/50	 Batch: 250/375	 Error: 0.598	 Accuracy: 0.75
# Epoch: 8/50	 Batch: 275/375	 Error: 0.530	 Accuracy: 0.81
# Epoch: 8/50	 Batch: 300/375	 Error: 0.655	 Accuracy: 0.75
# Epoch: 8/50	 Batch: 325/375	 Error: 0.747	 Accuracy: 0.72
# Epoch: 8/50	 Batch: 350/375	 Error: 1.407	 Accuracy: 0.62
# Epoch: 8/50	 Batch: 375/375	 Error: 0.794	 Accuracy: 0.74
#
#
# 	 Epoch: 8
# 	 Validation loss: 0.64
# 	 Validation accuracy: 0.79
# 	 Elapsed time: 116.8
#
#
# Epoch: 9/50	 Batch: 25/375	 Error: 0.703	 Accuracy: 0.75
# Epoch: 9/50	 Batch: 50/375	 Error: 0.819	 Accuracy: 0.78
# Epoch: 9/50	 Batch: 75/375	 Error: 0.506	 Accuracy: 0.84
# Epoch: 9/50	 Batch: 100/375	 Error: 0.658	 Accuracy: 0.81
# Epoch: 9/50	 Batch: 125/375	 Error: 0.593	 Accuracy: 0.81
# Epoch: 9/50	 Batch: 150/375	 Error: 0.591	 Accuracy: 0.78
# Epoch: 9/50	 Batch: 175/375	 Error: 0.751	 Accuracy: 0.72
# Epoch: 9/50	 Batch: 200/375	 Error: 0.610	 Accuracy: 0.81
# Epoch: 9/50	 Batch: 225/375	 Error: 0.569	 Accuracy: 0.84
# Epoch: 9/50	 Batch: 250/375	 Error: 0.606	 Accuracy: 0.78
# Epoch: 9/50	 Batch: 275/375	 Error: 0.493	 Accuracy: 0.91
# Epoch: 9/50	 Batch: 300/375	 Error: 0.406	 Accuracy: 0.84
# Epoch: 9/50	 Batch: 325/375	 Error: 0.937	 Accuracy: 0.69
# Epoch: 9/50	 Batch: 350/375	 Error: 0.597	 Accuracy: 0.75
# Epoch: 9/50	 Batch: 375/375	 Error: 0.543	 Accuracy: 0.93
#
#
# 	 Epoch: 9
# 	 Validation loss: 0.58
# 	 Validation accuracy: 0.82
# 	 Elapsed time: 131.0
#
#
# Epoch: 10/50	 Batch: 25/375	 Error: 0.631	 Accuracy: 0.81
# Epoch: 10/50	 Batch: 50/375	 Error: 0.463	 Accuracy: 0.88
# Epoch: 10/50	 Batch: 75/375	 Error: 0.576	 Accuracy: 0.72
# Epoch: 10/50	 Batch: 100/375	 Error: 0.559	 Accuracy: 0.81
# Epoch: 10/50	 Batch: 125/375	 Error: 0.945	 Accuracy: 0.62
# Epoch: 10/50	 Batch: 150/375	 Error: 0.912	 Accuracy: 0.66
# Epoch: 10/50	 Batch: 175/375	 Error: 0.961	 Accuracy: 0.72
# Epoch: 10/50	 Batch: 200/375	 Error: 0.669	 Accuracy: 0.75
# Epoch: 10/50	 Batch: 225/375	 Error: 0.658	 Accuracy: 0.72
# Epoch: 10/50	 Batch: 250/375	 Error: 0.867	 Accuracy: 0.66
# Epoch: 10/50	 Batch: 275/375	 Error: 0.532	 Accuracy: 0.81
# Epoch: 10/50	 Batch: 300/375	 Error: 0.697	 Accuracy: 0.81
# Epoch: 10/50	 Batch: 325/375	 Error: 0.643	 Accuracy: 0.75
# Epoch: 10/50	 Batch: 350/375	 Error: 0.924	 Accuracy: 0.69
# Epoch: 10/50	 Batch: 375/375	 Error: 0.565	 Accuracy: 0.81
#
#
# 	 Epoch: 10
# 	 Validation loss: 0.57
# 	 Validation accuracy: 0.82
# 	 Elapsed time: 146.1
#
#
# Epoch: 11/50	 Batch: 25/375	 Error: 0.459	 Accuracy: 0.91
# Epoch: 11/50	 Batch: 50/375	 Error: 0.525	 Accuracy: 0.81
# Epoch: 11/50	 Batch: 75/375	 Error: 0.409	 Accuracy: 0.84
# Epoch: 11/50	 Batch: 100/375	 Error: 0.611	 Accuracy: 0.81
# Epoch: 11/50	 Batch: 125/375	 Error: 0.564	 Accuracy: 0.78
# Epoch: 11/50	 Batch: 150/375	 Error: 0.666	 Accuracy: 0.78
# Epoch: 11/50	 Batch: 175/375	 Error: 0.775	 Accuracy: 0.66
# Epoch: 11/50	 Batch: 200/375	 Error: 0.779	 Accuracy: 0.75
# Epoch: 11/50	 Batch: 225/375	 Error: 0.467	 Accuracy: 0.81
# Epoch: 11/50	 Batch: 250/375	 Error: 0.459	 Accuracy: 0.84
# Epoch: 11/50	 Batch: 275/375	 Error: 0.417	 Accuracy: 0.91
# Epoch: 11/50	 Batch: 300/375	 Error: 0.483	 Accuracy: 0.88
# Epoch: 11/50	 Batch: 325/375	 Error: 1.138	 Accuracy: 0.72
# Epoch: 11/50	 Batch: 350/375	 Error: 0.689	 Accuracy: 0.75
# Epoch: 11/50	 Batch: 375/375	 Error: 0.573	 Accuracy: 0.81
#
#
# 	 Epoch: 11
# 	 Validation loss: 0.52
# 	 Validation accuracy: 0.84
# 	 Elapsed time: 160.3
#
#
# Epoch: 12/50	 Batch: 25/375	 Error: 0.540	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 50/375	 Error: 0.486	 Accuracy: 0.88
# Epoch: 12/50	 Batch: 75/375	 Error: 0.816	 Accuracy: 0.72
# Epoch: 12/50	 Batch: 100/375	 Error: 0.498	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 125/375	 Error: 0.906	 Accuracy: 0.62
# Epoch: 12/50	 Batch: 150/375	 Error: 0.676	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 175/375	 Error: 0.524	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 200/375	 Error: 0.540	 Accuracy: 0.88
# Epoch: 12/50	 Batch: 225/375	 Error: 0.715	 Accuracy: 0.84
# Epoch: 12/50	 Batch: 250/375	 Error: 0.687	 Accuracy: 0.78
# Epoch: 12/50	 Batch: 275/375	 Error: 0.593	 Accuracy: 0.81
# Epoch: 12/50	 Batch: 300/375	 Error: 0.903	 Accuracy: 0.72
# Epoch: 12/50	 Batch: 325/375	 Error: 0.708	 Accuracy: 0.75
# Epoch: 12/50	 Batch: 350/375	 Error: 0.467	 Accuracy: 0.84
# Epoch: 12/50	 Batch: 375/375	 Error: 0.557	 Accuracy: 0.74
#
#
# 	 Epoch: 12
# 	 Validation loss: 0.52
# 	 Validation accuracy: 0.84
# 	 Elapsed time: 174.6
#
#
# Epoch: 13/50	 Batch: 25/375	 Error: 0.694	 Accuracy: 0.78
# Epoch: 13/50	 Batch: 50/375	 Error: 0.664	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 75/375	 Error: 0.680	 Accuracy: 0.78
# Epoch: 13/50	 Batch: 100/375	 Error: 0.592	 Accuracy: 0.78
# Epoch: 13/50	 Batch: 125/375	 Error: 0.610	 Accuracy: 0.81
# Epoch: 13/50	 Batch: 150/375	 Error: 0.732	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 175/375	 Error: 0.573	 Accuracy: 0.78
# Epoch: 13/50	 Batch: 200/375	 Error: 0.768	 Accuracy: 0.75
# Epoch: 13/50	 Batch: 225/375	 Error: 0.943	 Accuracy: 0.69
# Epoch: 13/50	 Batch: 250/375	 Error: 0.364	 Accuracy: 0.88
# Epoch: 13/50	 Batch: 275/375	 Error: 0.825	 Accuracy: 0.72
# Epoch: 13/50	 Batch: 300/375	 Error: 0.609	 Accuracy: 0.69
# Epoch: 13/50	 Batch: 325/375	 Error: 0.595	 Accuracy: 0.84
# Epoch: 13/50	 Batch: 350/375	 Error: 0.785	 Accuracy: 0.81
# Epoch: 13/50	 Batch: 375/375	 Error: 0.392	 Accuracy: 0.89
#
#
# 	 Epoch: 13
# 	 Validation loss: 0.51
# 	 Validation accuracy: 0.84
# 	 Elapsed time: 189.1
#
#
# Epoch: 14/50	 Batch: 25/375	 Error: 0.506	 Accuracy: 0.81
# Epoch: 14/50	 Batch: 50/375	 Error: 0.421	 Accuracy: 0.84
# Epoch: 14/50	 Batch: 75/375	 Error: 1.669	 Accuracy: 0.53
# Epoch: 14/50	 Batch: 100/375	 Error: 0.293	 Accuracy: 0.94
# Epoch: 14/50	 Batch: 125/375	 Error: 0.793	 Accuracy: 0.75
# Epoch: 14/50	 Batch: 150/375	 Error: 0.738	 Accuracy: 0.78
# Epoch: 14/50	 Batch: 175/375	 Error: 0.375	 Accuracy: 0.91
# Epoch: 14/50	 Batch: 200/375	 Error: 0.410	 Accuracy: 0.81
# Epoch: 14/50	 Batch: 225/375	 Error: 0.479	 Accuracy: 0.88
# Epoch: 14/50	 Batch: 250/375	 Error: 0.810	 Accuracy: 0.75
# Epoch: 14/50	 Batch: 275/375	 Error: 0.396	 Accuracy: 0.88
# Epoch: 14/50	 Batch: 300/375	 Error: 0.574	 Accuracy: 0.81
# Epoch: 14/50	 Batch: 325/375	 Error: 0.542	 Accuracy: 0.84
# Epoch: 14/50	 Batch: 350/375	 Error: 0.574	 Accuracy: 0.81
# Epoch: 14/50	 Batch: 375/375	 Error: 0.549	 Accuracy: 0.85
#
#
# 	 Epoch: 14
# 	 Validation loss: 0.51
# 	 Validation accuracy: 0.83
# 	 Elapsed time: 201.8
#
#
# Epoch: 15/50	 Batch: 25/375	 Error: 0.654	 Accuracy: 0.78
# Epoch: 15/50	 Batch: 50/375	 Error: 0.481	 Accuracy: 0.84
# Epoch: 15/50	 Batch: 75/375	 Error: 0.554	 Accuracy: 0.78
# Epoch: 15/50	 Batch: 100/375	 Error: 0.368	 Accuracy: 0.88
# Epoch: 15/50	 Batch: 125/375	 Error: 0.420	 Accuracy: 0.94
# Epoch: 15/50	 Batch: 150/375	 Error: 0.568	 Accuracy: 0.78
# Epoch: 15/50	 Batch: 175/375	 Error: 0.657	 Accuracy: 0.78
# Epoch: 15/50	 Batch: 200/375	 Error: 0.500	 Accuracy: 0.75
# Epoch: 15/50	 Batch: 225/375	 Error: 0.541	 Accuracy: 0.78
# Epoch: 15/50	 Batch: 250/375	 Error: 0.910	 Accuracy: 0.72
# Epoch: 15/50	 Batch: 275/375	 Error: 0.579	 Accuracy: 0.75
# Epoch: 15/50	 Batch: 300/375	 Error: 0.480	 Accuracy: 0.81
# Epoch: 15/50	 Batch: 325/375	 Error: 0.696	 Accuracy: 0.69
# Epoch: 15/50	 Batch: 350/375	 Error: 0.613	 Accuracy: 0.78
# Epoch: 15/50	 Batch: 375/375	 Error: 0.762	 Accuracy: 0.81
#
#
# 	 Epoch: 15
# 	 Validation loss: 0.47
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 216.2
#
#
# Epoch: 16/50	 Batch: 25/375	 Error: 0.709	 Accuracy: 0.72
# Epoch: 16/50	 Batch: 50/375	 Error: 0.778	 Accuracy: 0.69
# Epoch: 16/50	 Batch: 75/375	 Error: 0.491	 Accuracy: 0.88
# Epoch: 16/50	 Batch: 100/375	 Error: 0.476	 Accuracy: 0.84
# Epoch: 16/50	 Batch: 125/375	 Error: 0.736	 Accuracy: 0.84
# Epoch: 16/50	 Batch: 150/375	 Error: 0.327	 Accuracy: 0.91
# Epoch: 16/50	 Batch: 175/375	 Error: 1.203	 Accuracy: 0.62
# Epoch: 16/50	 Batch: 200/375	 Error: 1.078	 Accuracy: 0.59
# Epoch: 16/50	 Batch: 225/375	 Error: 0.961	 Accuracy: 0.66
# Epoch: 16/50	 Batch: 250/375	 Error: 0.468	 Accuracy: 0.78
# Epoch: 16/50	 Batch: 275/375	 Error: 0.902	 Accuracy: 0.72
# Epoch: 16/50	 Batch: 300/375	 Error: 0.451	 Accuracy: 0.84
# Epoch: 16/50	 Batch: 325/375	 Error: 0.572	 Accuracy: 0.78
# Epoch: 16/50	 Batch: 350/375	 Error: 0.629	 Accuracy: 0.81
# Epoch: 16/50	 Batch: 375/375	 Error: 0.644	 Accuracy: 0.78
#
#
# 	 Epoch: 16
# 	 Validation loss: 0.47
# 	 Validation accuracy: 0.85
# 	 Elapsed time: 230.6
#
#
# Epoch: 17/50	 Batch: 25/375	 Error: 0.378	 Accuracy: 0.91
# Epoch: 17/50	 Batch: 50/375	 Error: 0.718	 Accuracy: 0.75
# Epoch: 17/50	 Batch: 75/375	 Error: 0.484	 Accuracy: 0.81
# Epoch: 17/50	 Batch: 100/375	 Error: 0.763	 Accuracy: 0.72
# Epoch: 17/50	 Batch: 125/375	 Error: 0.513	 Accuracy: 0.78
# Epoch: 17/50	 Batch: 150/375	 Error: 0.418	 Accuracy: 0.88
# Epoch: 17/50	 Batch: 175/375	 Error: 0.527	 Accuracy: 0.78
# Epoch: 17/50	 Batch: 200/375	 Error: 0.434	 Accuracy: 0.91
# Epoch: 17/50	 Batch: 225/375	 Error: 0.771	 Accuracy: 0.72
# Epoch: 17/50	 Batch: 250/375	 Error: 0.956	 Accuracy: 0.72
# Epoch: 17/50	 Batch: 275/375	 Error: 0.498	 Accuracy: 0.84
# Epoch: 17/50	 Batch: 300/375	 Error: 0.435	 Accuracy: 0.81
# Epoch: 17/50	 Batch: 325/375	 Error: 0.618	 Accuracy: 0.81
# Epoch: 17/50	 Batch: 350/375	 Error: 0.358	 Accuracy: 0.84
# Epoch: 17/50	 Batch: 375/375	 Error: 0.611	 Accuracy: 0.74
#
#
# 	 Epoch: 17
# 	 Validation loss: 0.47
# 	 Validation accuracy: 0.85
# 	 Elapsed time: 244.8
#
#
# Epoch: 18/50	 Batch: 25/375	 Error: 0.328	 Accuracy: 0.88
# Epoch: 18/50	 Batch: 50/375	 Error: 0.257	 Accuracy: 0.94
# Epoch: 18/50	 Batch: 75/375	 Error: 0.828	 Accuracy: 0.69
# Epoch: 18/50	 Batch: 100/375	 Error: 0.455	 Accuracy: 0.88
# Epoch: 18/50	 Batch: 125/375	 Error: 0.680	 Accuracy: 0.84
# Epoch: 18/50	 Batch: 150/375	 Error: 0.530	 Accuracy: 0.72
# Epoch: 18/50	 Batch: 175/375	 Error: 0.542	 Accuracy: 0.72
# Epoch: 18/50	 Batch: 200/375	 Error: 0.412	 Accuracy: 0.88
# Epoch: 18/50	 Batch: 225/375	 Error: 0.466	 Accuracy: 0.81
# Epoch: 18/50	 Batch: 250/375	 Error: 0.512	 Accuracy: 0.84
# Epoch: 18/50	 Batch: 275/375	 Error: 0.512	 Accuracy: 0.81
# Epoch: 18/50	 Batch: 300/375	 Error: 0.494	 Accuracy: 0.88
# Epoch: 18/50	 Batch: 325/375	 Error: 0.525	 Accuracy: 0.81
# Epoch: 18/50	 Batch: 350/375	 Error: 0.382	 Accuracy: 0.88
# Epoch: 18/50	 Batch: 375/375	 Error: 0.445	 Accuracy: 0.78
#
#
# 	 Epoch: 18
# 	 Validation loss: 0.45
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 258.9
#
#
# Epoch: 19/50	 Batch: 25/375	 Error: 0.376	 Accuracy: 0.91
# Epoch: 19/50	 Batch: 50/375	 Error: 0.462	 Accuracy: 0.84
# Epoch: 19/50	 Batch: 75/375	 Error: 0.774	 Accuracy: 0.78
# Epoch: 19/50	 Batch: 100/375	 Error: 0.731	 Accuracy: 0.72
# Epoch: 19/50	 Batch: 125/375	 Error: 0.336	 Accuracy: 0.91
# Epoch: 19/50	 Batch: 150/375	 Error: 0.276	 Accuracy: 0.91
# Epoch: 19/50	 Batch: 175/375	 Error: 0.517	 Accuracy: 0.81
# Epoch: 19/50	 Batch: 200/375	 Error: 0.412	 Accuracy: 0.88
# Epoch: 19/50	 Batch: 225/375	 Error: 0.354	 Accuracy: 0.91
# Epoch: 19/50	 Batch: 250/375	 Error: 0.578	 Accuracy: 0.81
# Epoch: 19/50	 Batch: 275/375	 Error: 0.686	 Accuracy: 0.75
# Epoch: 19/50	 Batch: 300/375	 Error: 0.346	 Accuracy: 0.94
# Epoch: 19/50	 Batch: 325/375	 Error: 0.325	 Accuracy: 0.88
# Epoch: 19/50	 Batch: 350/375	 Error: 0.541	 Accuracy: 0.88
# Epoch: 19/50	 Batch: 375/375	 Error: 0.587	 Accuracy: 0.78
#
#
# 	 Epoch: 19
# 	 Validation loss: 0.44
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 273.3
#
#
# Epoch: 20/50	 Batch: 25/375	 Error: 0.425	 Accuracy: 0.91
# Epoch: 20/50	 Batch: 50/375	 Error: 0.356	 Accuracy: 0.88
# Epoch: 20/50	 Batch: 75/375	 Error: 0.251	 Accuracy: 0.94
# Epoch: 20/50	 Batch: 100/375	 Error: 0.330	 Accuracy: 0.94
# Epoch: 20/50	 Batch: 125/375	 Error: 0.362	 Accuracy: 0.84
# Epoch: 20/50	 Batch: 150/375	 Error: 0.653	 Accuracy: 0.81
# Epoch: 20/50	 Batch: 175/375	 Error: 0.549	 Accuracy: 0.81
# Epoch: 20/50	 Batch: 200/375	 Error: 0.527	 Accuracy: 0.84
# Epoch: 20/50	 Batch: 225/375	 Error: 0.317	 Accuracy: 0.84
# Epoch: 20/50	 Batch: 250/375	 Error: 0.363	 Accuracy: 0.84
# Epoch: 20/50	 Batch: 275/375	 Error: 0.770	 Accuracy: 0.75
# Epoch: 20/50	 Batch: 300/375	 Error: 0.454	 Accuracy: 0.81
# Epoch: 20/50	 Batch: 325/375	 Error: 0.508	 Accuracy: 0.84
# Epoch: 20/50	 Batch: 350/375	 Error: 0.504	 Accuracy: 0.84
# Epoch: 20/50	 Batch: 375/375	 Error: 0.789	 Accuracy: 0.78
#
#
# 	 Epoch: 20
# 	 Validation loss: 0.44
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 286.0
#
#
# Epoch: 21/50	 Batch: 25/375	 Error: 0.397	 Accuracy: 0.88
# Epoch: 21/50	 Batch: 50/375	 Error: 0.459	 Accuracy: 0.75
# Epoch: 21/50	 Batch: 75/375	 Error: 0.592	 Accuracy: 0.84
# Epoch: 21/50	 Batch: 100/375	 Error: 0.598	 Accuracy: 0.84
# Epoch: 21/50	 Batch: 125/375	 Error: 0.578	 Accuracy: 0.81
# Epoch: 21/50	 Batch: 150/375	 Error: 0.194	 Accuracy: 0.94
# Epoch: 21/50	 Batch: 175/375	 Error: 0.521	 Accuracy: 0.78
# Epoch: 21/50	 Batch: 200/375	 Error: 0.236	 Accuracy: 0.94
# Epoch: 21/50	 Batch: 225/375	 Error: 0.157	 Accuracy: 1.00
# Epoch: 21/50	 Batch: 250/375	 Error: 0.805	 Accuracy: 0.72
# Epoch: 21/50	 Batch: 275/375	 Error: 0.149	 Accuracy: 0.94
# Epoch: 21/50	 Batch: 300/375	 Error: 0.399	 Accuracy: 0.84
# Epoch: 21/50	 Batch: 325/375	 Error: 0.475	 Accuracy: 0.84
# Epoch: 21/50	 Batch: 350/375	 Error: 0.328	 Accuracy: 0.88
# Epoch: 21/50	 Batch: 375/375	 Error: 0.705	 Accuracy: 0.81
#
#
# 	 Epoch: 21
# 	 Validation loss: 0.43
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 298.7
#
#
# Epoch: 22/50	 Batch: 25/375	 Error: 0.420	 Accuracy: 0.81
# Epoch: 22/50	 Batch: 50/375	 Error: 0.367	 Accuracy: 0.84
# Epoch: 22/50	 Batch: 75/375	 Error: 0.519	 Accuracy: 0.84
# Epoch: 22/50	 Batch: 100/375	 Error: 0.686	 Accuracy: 0.84
# Epoch: 22/50	 Batch: 125/375	 Error: 0.191	 Accuracy: 0.97
# Epoch: 22/50	 Batch: 150/375	 Error: 0.717	 Accuracy: 0.78
# Epoch: 22/50	 Batch: 175/375	 Error: 0.413	 Accuracy: 0.84
# Epoch: 22/50	 Batch: 200/375	 Error: 0.343	 Accuracy: 0.88
# Epoch: 22/50	 Batch: 225/375	 Error: 0.210	 Accuracy: 0.91
# Epoch: 22/50	 Batch: 250/375	 Error: 0.400	 Accuracy: 0.88
# Epoch: 22/50	 Batch: 275/375	 Error: 0.611	 Accuracy: 0.78
# Epoch: 22/50	 Batch: 300/375	 Error: 0.229	 Accuracy: 0.94
# Epoch: 22/50	 Batch: 325/375	 Error: 0.436	 Accuracy: 0.81
# Epoch: 22/50	 Batch: 350/375	 Error: 0.161	 Accuracy: 0.97
# Epoch: 22/50	 Batch: 375/375	 Error: 0.596	 Accuracy: 0.81
#
#
# 	 Epoch: 22
# 	 Validation loss: 0.43
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 312.3
#
#
# Epoch: 23/50	 Batch: 25/375	 Error: 0.341	 Accuracy: 0.84
# Epoch: 23/50	 Batch: 50/375	 Error: 0.373	 Accuracy: 0.84
# Epoch: 23/50	 Batch: 75/375	 Error: 0.369	 Accuracy: 0.84
# Epoch: 23/50	 Batch: 100/375	 Error: 0.667	 Accuracy: 0.84
# Epoch: 23/50	 Batch: 125/375	 Error: 0.595	 Accuracy: 0.84
# Epoch: 23/50	 Batch: 150/375	 Error: 0.326	 Accuracy: 0.88
# Epoch: 23/50	 Batch: 175/375	 Error: 0.407	 Accuracy: 0.91
# Epoch: 23/50	 Batch: 200/375	 Error: 0.340	 Accuracy: 0.84
# Epoch: 23/50	 Batch: 225/375	 Error: 0.469	 Accuracy: 0.88
# Epoch: 23/50	 Batch: 250/375	 Error: 0.287	 Accuracy: 0.94
# Epoch: 23/50	 Batch: 275/375	 Error: 0.276	 Accuracy: 0.91
# Epoch: 23/50	 Batch: 300/375	 Error: 0.710	 Accuracy: 0.72
# Epoch: 23/50	 Batch: 325/375	 Error: 0.799	 Accuracy: 0.72
# Epoch: 23/50	 Batch: 350/375	 Error: 0.733	 Accuracy: 0.78
# Epoch: 23/50	 Batch: 375/375	 Error: 0.372	 Accuracy: 0.89
#
#
# 	 Epoch: 23
# 	 Validation loss: 0.43
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 325.3
#
#
# Epoch: 24/50	 Batch: 25/375	 Error: 0.588	 Accuracy: 0.78
# Epoch: 24/50	 Batch: 50/375	 Error: 0.399	 Accuracy: 0.88
# Epoch: 24/50	 Batch: 75/375	 Error: 0.569	 Accuracy: 0.78
# Epoch: 24/50	 Batch: 100/375	 Error: 0.515	 Accuracy: 0.81
# Epoch: 24/50	 Batch: 125/375	 Error: 0.418	 Accuracy: 0.88
# Epoch: 24/50	 Batch: 150/375	 Error: 0.285	 Accuracy: 0.94
# Epoch: 24/50	 Batch: 175/375	 Error: 0.338	 Accuracy: 0.91
# Epoch: 24/50	 Batch: 200/375	 Error: 0.376	 Accuracy: 0.91
# Epoch: 24/50	 Batch: 225/375	 Error: 0.233	 Accuracy: 0.94
# Epoch: 24/50	 Batch: 250/375	 Error: 0.527	 Accuracy: 0.78
# Epoch: 24/50	 Batch: 275/375	 Error: 0.723	 Accuracy: 0.75
# Epoch: 24/50	 Batch: 300/375	 Error: 0.515	 Accuracy: 0.78
# Epoch: 24/50	 Batch: 325/375	 Error: 0.407	 Accuracy: 0.81
# Epoch: 24/50	 Batch: 350/375	 Error: 0.910	 Accuracy: 0.72
# Epoch: 24/50	 Batch: 375/375	 Error: 0.174	 Accuracy: 0.96
#
#
# 	 Epoch: 24
# 	 Validation loss: 0.42
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 338.2
#
#
# Epoch: 25/50	 Batch: 25/375	 Error: 0.356	 Accuracy: 0.81
# Epoch: 25/50	 Batch: 50/375	 Error: 0.567	 Accuracy: 0.81
# Epoch: 25/50	 Batch: 75/375	 Error: 0.303	 Accuracy: 0.91
# Epoch: 25/50	 Batch: 100/375	 Error: 0.418	 Accuracy: 0.88
# Epoch: 25/50	 Batch: 125/375	 Error: 0.209	 Accuracy: 0.97
# Epoch: 25/50	 Batch: 150/375	 Error: 0.353	 Accuracy: 0.88
# Epoch: 25/50	 Batch: 175/375	 Error: 0.596	 Accuracy: 0.62
# Epoch: 25/50	 Batch: 200/375	 Error: 0.480	 Accuracy: 0.81
# Epoch: 25/50	 Batch: 225/375	 Error: 0.701	 Accuracy: 0.78
# Epoch: 25/50	 Batch: 250/375	 Error: 0.332	 Accuracy: 0.91
# Epoch: 25/50	 Batch: 275/375	 Error: 0.466	 Accuracy: 0.84
# Epoch: 25/50	 Batch: 300/375	 Error: 0.491	 Accuracy: 0.88
# Epoch: 25/50	 Batch: 325/375	 Error: 0.625	 Accuracy: 0.78
# Epoch: 25/50	 Batch: 350/375	 Error: 0.215	 Accuracy: 0.94
# Epoch: 25/50	 Batch: 375/375	 Error: 0.236	 Accuracy: 0.93
#
#
# 	 Epoch: 25
# 	 Validation loss: 0.42
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 351.0
#
#
# Epoch: 26/50	 Batch: 25/375	 Error: 0.609	 Accuracy: 0.84
# Epoch: 26/50	 Batch: 50/375	 Error: 0.349	 Accuracy: 0.88
# Epoch: 26/50	 Batch: 75/375	 Error: 0.524	 Accuracy: 0.88
# Epoch: 26/50	 Batch: 100/375	 Error: 0.340	 Accuracy: 0.84
# Epoch: 26/50	 Batch: 125/375	 Error: 0.525	 Accuracy: 0.84
# Epoch: 26/50	 Batch: 150/375	 Error: 0.246	 Accuracy: 0.91
# Epoch: 26/50	 Batch: 175/375	 Error: 0.265	 Accuracy: 0.91
# Epoch: 26/50	 Batch: 200/375	 Error: 0.458	 Accuracy: 0.84
# Epoch: 26/50	 Batch: 225/375	 Error: 0.470	 Accuracy: 0.78
# Epoch: 26/50	 Batch: 250/375	 Error: 0.584	 Accuracy: 0.78
# Epoch: 26/50	 Batch: 275/375	 Error: 0.369	 Accuracy: 0.88
# Epoch: 26/50	 Batch: 300/375	 Error: 0.716	 Accuracy: 0.72
# Epoch: 26/50	 Batch: 325/375	 Error: 0.311	 Accuracy: 0.88
# Epoch: 26/50	 Batch: 350/375	 Error: 0.510	 Accuracy: 0.81
# Epoch: 26/50	 Batch: 375/375	 Error: 0.505	 Accuracy: 0.81
#
#
# 	 Epoch: 26
# 	 Validation loss: 0.44
# 	 Validation accuracy: 0.85
# 	 Elapsed time: 367.0
#
#
# Epoch: 27/50	 Batch: 25/375	 Error: 0.193	 Accuracy: 0.94
# Epoch: 27/50	 Batch: 50/375	 Error: 0.627	 Accuracy: 0.78
# Epoch: 27/50	 Batch: 75/375	 Error: 0.241	 Accuracy: 0.91
# Epoch: 27/50	 Batch: 100/375	 Error: 0.271	 Accuracy: 0.91
# Epoch: 27/50	 Batch: 125/375	 Error: 0.790	 Accuracy: 0.72
# Epoch: 27/50	 Batch: 150/375	 Error: 0.583	 Accuracy: 0.81
# Epoch: 27/50	 Batch: 175/375	 Error: 0.252	 Accuracy: 0.94
# Epoch: 27/50	 Batch: 200/375	 Error: 0.327	 Accuracy: 0.84
# Epoch: 27/50	 Batch: 225/375	 Error: 0.394	 Accuracy: 0.88
# Epoch: 27/50	 Batch: 250/375	 Error: 0.176	 Accuracy: 0.94
# Epoch: 27/50	 Batch: 275/375	 Error: 0.267	 Accuracy: 0.91
# Epoch: 27/50	 Batch: 300/375	 Error: 0.489	 Accuracy: 0.84
# Epoch: 27/50	 Batch: 325/375	 Error: 0.376	 Accuracy: 0.84
# Epoch: 27/50	 Batch: 350/375	 Error: 0.479	 Accuracy: 0.75
# Epoch: 27/50	 Batch: 375/375	 Error: 0.414	 Accuracy: 0.93
#
#
# 	 Epoch: 27
# 	 Validation loss: 0.41
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 380.1
#
#
# Epoch: 28/50	 Batch: 25/375	 Error: 0.454	 Accuracy: 0.81
# Epoch: 28/50	 Batch: 50/375	 Error: 0.333	 Accuracy: 0.91
# Epoch: 28/50	 Batch: 75/375	 Error: 0.655	 Accuracy: 0.88
# Epoch: 28/50	 Batch: 100/375	 Error: 0.716	 Accuracy: 0.66
# Epoch: 28/50	 Batch: 125/375	 Error: 0.593	 Accuracy: 0.84
# Epoch: 28/50	 Batch: 150/375	 Error: 0.333	 Accuracy: 0.84
# Epoch: 28/50	 Batch: 175/375	 Error: 0.375	 Accuracy: 0.88
# Epoch: 28/50	 Batch: 200/375	 Error: 0.361	 Accuracy: 0.88
# Epoch: 28/50	 Batch: 225/375	 Error: 0.516	 Accuracy: 0.81
# Epoch: 28/50	 Batch: 250/375	 Error: 0.353	 Accuracy: 0.81
# Epoch: 28/50	 Batch: 275/375	 Error: 0.497	 Accuracy: 0.81
# Epoch: 28/50	 Batch: 300/375	 Error: 0.658	 Accuracy: 0.78
# Epoch: 28/50	 Batch: 325/375	 Error: 0.429	 Accuracy: 0.81
# Epoch: 28/50	 Batch: 350/375	 Error: 0.222	 Accuracy: 0.94
# Epoch: 28/50	 Batch: 375/375	 Error: 0.670	 Accuracy: 0.81
#
#
# 	 Epoch: 28
# 	 Validation loss: 0.42
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 393.1
#
#
# Epoch: 29/50	 Batch: 25/375	 Error: 0.554	 Accuracy: 0.81
# Epoch: 29/50	 Batch: 50/375	 Error: 0.351	 Accuracy: 0.84
# Epoch: 29/50	 Batch: 75/375	 Error: 0.379	 Accuracy: 0.88
# Epoch: 29/50	 Batch: 100/375	 Error: 0.515	 Accuracy: 0.75
# Epoch: 29/50	 Batch: 125/375	 Error: 0.327	 Accuracy: 0.88
# Epoch: 29/50	 Batch: 150/375	 Error: 0.195	 Accuracy: 0.94
# Epoch: 29/50	 Batch: 175/375	 Error: 0.499	 Accuracy: 0.78
# Epoch: 29/50	 Batch: 200/375	 Error: 0.236	 Accuracy: 0.97
# Epoch: 29/50	 Batch: 225/375	 Error: 0.208	 Accuracy: 0.88
# Epoch: 29/50	 Batch: 250/375	 Error: 0.678	 Accuracy: 0.75
# Epoch: 29/50	 Batch: 275/375	 Error: 0.679	 Accuracy: 0.78
# Epoch: 29/50	 Batch: 300/375	 Error: 0.187	 Accuracy: 0.94
# Epoch: 29/50	 Batch: 325/375	 Error: 0.207	 Accuracy: 0.97
# Epoch: 29/50	 Batch: 350/375	 Error: 0.381	 Accuracy: 0.81
# Epoch: 29/50	 Batch: 375/375	 Error: 0.516	 Accuracy: 0.81
#
#
# 	 Epoch: 29
# 	 Validation loss: 0.42
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 406.0
#
#
# Epoch: 30/50	 Batch: 25/375	 Error: 0.628	 Accuracy: 0.75
# Epoch: 30/50	 Batch: 50/375	 Error: 0.546	 Accuracy: 0.84
# Epoch: 30/50	 Batch: 75/375	 Error: 0.318	 Accuracy: 0.88
# Epoch: 30/50	 Batch: 100/375	 Error: 0.286	 Accuracy: 0.94
# Epoch: 30/50	 Batch: 125/375	 Error: 0.525	 Accuracy: 0.84
# Epoch: 30/50	 Batch: 150/375	 Error: 0.641	 Accuracy: 0.84
# Epoch: 30/50	 Batch: 175/375	 Error: 0.538	 Accuracy: 0.78
# Epoch: 30/50	 Batch: 200/375	 Error: 0.268	 Accuracy: 0.91
# Epoch: 30/50	 Batch: 225/375	 Error: 0.545	 Accuracy: 0.81
# Epoch: 30/50	 Batch: 250/375	 Error: 0.560	 Accuracy: 0.78
# Epoch: 30/50	 Batch: 275/375	 Error: 0.541	 Accuracy: 0.78
# Epoch: 30/50	 Batch: 300/375	 Error: 0.204	 Accuracy: 0.91
# Epoch: 30/50	 Batch: 325/375	 Error: 0.455	 Accuracy: 0.78
# Epoch: 30/50	 Batch: 350/375	 Error: 0.280	 Accuracy: 0.88
# Epoch: 30/50	 Batch: 375/375	 Error: 0.489	 Accuracy: 0.85
#
#
# 	 Epoch: 30
# 	 Validation loss: 0.41
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 418.9
#
#
# Epoch: 31/50	 Batch: 25/375	 Error: 0.497	 Accuracy: 0.81
# Epoch: 31/50	 Batch: 50/375	 Error: 0.211	 Accuracy: 0.94
# Epoch: 31/50	 Batch: 75/375	 Error: 0.388	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 100/375	 Error: 0.436	 Accuracy: 0.78
# Epoch: 31/50	 Batch: 125/375	 Error: 0.428	 Accuracy: 0.88
# Epoch: 31/50	 Batch: 150/375	 Error: 0.271	 Accuracy: 0.88
# Epoch: 31/50	 Batch: 175/375	 Error: 0.415	 Accuracy: 0.78
# Epoch: 31/50	 Batch: 200/375	 Error: 0.547	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 225/375	 Error: 0.550	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 250/375	 Error: 0.218	 Accuracy: 0.94
# Epoch: 31/50	 Batch: 275/375	 Error: 0.346	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 300/375	 Error: 0.321	 Accuracy: 0.91
# Epoch: 31/50	 Batch: 325/375	 Error: 0.512	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 350/375	 Error: 0.494	 Accuracy: 0.84
# Epoch: 31/50	 Batch: 375/375	 Error: 0.471	 Accuracy: 0.78
#
#
# 	 Epoch: 31
# 	 Validation loss: 0.40
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 431.7
#
#
# Epoch: 32/50	 Batch: 25/375	 Error: 0.597	 Accuracy: 0.78
# Epoch: 32/50	 Batch: 50/375	 Error: 0.448	 Accuracy: 0.84
# Epoch: 32/50	 Batch: 75/375	 Error: 0.549	 Accuracy: 0.78
# Epoch: 32/50	 Batch: 100/375	 Error: 0.279	 Accuracy: 0.94
# Epoch: 32/50	 Batch: 125/375	 Error: 0.409	 Accuracy: 0.88
# Epoch: 32/50	 Batch: 150/375	 Error: 0.330	 Accuracy: 0.84
# Epoch: 32/50	 Batch: 175/375	 Error: 0.375	 Accuracy: 0.88
# Epoch: 32/50	 Batch: 200/375	 Error: 0.301	 Accuracy: 0.94
# Epoch: 32/50	 Batch: 225/375	 Error: 0.357	 Accuracy: 0.81
# Epoch: 32/50	 Batch: 250/375	 Error: 0.513	 Accuracy: 0.88
# Epoch: 32/50	 Batch: 275/375	 Error: 0.444	 Accuracy: 0.75
# Epoch: 32/50	 Batch: 300/375	 Error: 0.784	 Accuracy: 0.69
# Epoch: 32/50	 Batch: 325/375	 Error: 0.503	 Accuracy: 0.84
# Epoch: 32/50	 Batch: 350/375	 Error: 0.520	 Accuracy: 0.78
# Epoch: 32/50	 Batch: 375/375	 Error: 0.240	 Accuracy: 0.93
#
#
# 	 Epoch: 32
# 	 Validation loss: 0.40
# 	 Validation accuracy: 0.86
# 	 Elapsed time: 444.4
#
#
# Epoch: 33/50	 Batch: 25/375	 Error: 0.486	 Accuracy: 0.84
# Epoch: 33/50	 Batch: 50/375	 Error: 0.374	 Accuracy: 0.88
# Epoch: 33/50	 Batch: 75/375	 Error: 0.587	 Accuracy: 0.78
# Epoch: 33/50	 Batch: 100/375	 Error: 0.279	 Accuracy: 0.91
# Epoch: 33/50	 Batch: 125/375	 Error: 0.361	 Accuracy: 0.84
# Epoch: 33/50	 Batch: 150/375	 Error: 0.411	 Accuracy: 0.84
# Epoch: 33/50	 Batch: 175/375	 Error: 0.367	 Accuracy: 0.88
# Epoch: 33/50	 Batch: 200/375	 Error: 0.296	 Accuracy: 0.91
# Epoch: 33/50	 Batch: 225/375	 Error: 0.801	 Accuracy: 0.66
# Epoch: 33/50	 Batch: 250/375	 Error: 0.197	 Accuracy: 0.94
# Epoch: 33/50	 Batch: 275/375	 Error: 0.193	 Accuracy: 0.97
# Epoch: 33/50	 Batch: 300/375	 Error: 0.295	 Accuracy: 0.94
# Epoch: 33/50	 Batch: 325/375	 Error: 0.553	 Accuracy: 0.81
# Epoch: 33/50	 Batch: 350/375	 Error: 0.299	 Accuracy: 0.91
# Epoch: 33/50	 Batch: 375/375	 Error: 0.378	 Accuracy: 0.85
#
#
# 	 Epoch: 33
# 	 Validation loss: 0.41
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 457.4
#
#
# Epoch: 34/50	 Batch: 25/375	 Error: 0.668	 Accuracy: 0.81
# Epoch: 34/50	 Batch: 50/375	 Error: 0.167	 Accuracy: 0.94
# Epoch: 34/50	 Batch: 75/375	 Error: 0.193	 Accuracy: 0.94
# Epoch: 34/50	 Batch: 100/375	 Error: 0.277	 Accuracy: 0.91
# Epoch: 34/50	 Batch: 125/375	 Error: 0.749	 Accuracy: 0.72
# Epoch: 34/50	 Batch: 150/375	 Error: 0.192	 Accuracy: 0.94
# Epoch: 34/50	 Batch: 175/375	 Error: 0.623	 Accuracy: 0.78
# Epoch: 34/50	 Batch: 200/375	 Error: 0.345	 Accuracy: 0.91
# Epoch: 34/50	 Batch: 225/375	 Error: 0.289	 Accuracy: 0.91
# Epoch: 34/50	 Batch: 250/375	 Error: 0.220	 Accuracy: 0.91
# Epoch: 34/50	 Batch: 275/375	 Error: 0.264	 Accuracy: 0.94
# Epoch: 34/50	 Batch: 300/375	 Error: 0.417	 Accuracy: 0.81
# Epoch: 34/50	 Batch: 325/375	 Error: 0.250	 Accuracy: 0.91
# Epoch: 34/50	 Batch: 350/375	 Error: 0.447	 Accuracy: 0.88
# Epoch: 34/50	 Batch: 375/375	 Error: 0.693	 Accuracy: 0.78
#
#
# 	 Epoch: 34
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 470.2
#
#
# Epoch: 35/50	 Batch: 25/375	 Error: 0.123	 Accuracy: 1.00
# Epoch: 35/50	 Batch: 50/375	 Error: 0.238	 Accuracy: 0.88
# Epoch: 35/50	 Batch: 75/375	 Error: 0.303	 Accuracy: 0.94
# Epoch: 35/50	 Batch: 100/375	 Error: 0.456	 Accuracy: 0.84
# Epoch: 35/50	 Batch: 125/375	 Error: 0.441	 Accuracy: 0.88
# Epoch: 35/50	 Batch: 150/375	 Error: 0.210	 Accuracy: 0.94
# Epoch: 35/50	 Batch: 175/375	 Error: 0.453	 Accuracy: 0.78
# Epoch: 35/50	 Batch: 200/375	 Error: 0.357	 Accuracy: 0.88
# Epoch: 35/50	 Batch: 225/375	 Error: 0.632	 Accuracy: 0.81
# Epoch: 35/50	 Batch: 250/375	 Error: 0.210	 Accuracy: 0.94
# Epoch: 35/50	 Batch: 275/375	 Error: 0.443	 Accuracy: 0.84
# Epoch: 35/50	 Batch: 300/375	 Error: 0.333	 Accuracy: 0.84
# Epoch: 35/50	 Batch: 325/375	 Error: 0.312	 Accuracy: 0.88
# Epoch: 35/50	 Batch: 350/375	 Error: 0.303	 Accuracy: 0.88
# Epoch: 35/50	 Batch: 375/375	 Error: 0.294	 Accuracy: 0.93
#
#
# 	 Epoch: 35
# 	 Validation loss: 0.38
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 483.0
#
#
# Epoch: 36/50	 Batch: 25/375	 Error: 0.270	 Accuracy: 0.91
# Epoch: 36/50	 Batch: 50/375	 Error: 0.297	 Accuracy: 0.88
# Epoch: 36/50	 Batch: 75/375	 Error: 0.193	 Accuracy: 0.91
# Epoch: 36/50	 Batch: 100/375	 Error: 0.340	 Accuracy: 0.84
# Epoch: 36/50	 Batch: 125/375	 Error: 0.136	 Accuracy: 1.00
# Epoch: 36/50	 Batch: 150/375	 Error: 0.285	 Accuracy: 0.88
# Epoch: 36/50	 Batch: 175/375	 Error: 0.181	 Accuracy: 0.97
# Epoch: 36/50	 Batch: 200/375	 Error: 0.195	 Accuracy: 0.97
# Epoch: 36/50	 Batch: 225/375	 Error: 0.560	 Accuracy: 0.78
# Epoch: 36/50	 Batch: 250/375	 Error: 0.316	 Accuracy: 0.88
# Epoch: 36/50	 Batch: 275/375	 Error: 0.270	 Accuracy: 0.88
# Epoch: 36/50	 Batch: 300/375	 Error: 0.448	 Accuracy: 0.84
# Epoch: 36/50	 Batch: 325/375	 Error: 0.131	 Accuracy: 1.00
# Epoch: 36/50	 Batch: 350/375	 Error: 0.602	 Accuracy: 0.69
# Epoch: 36/50	 Batch: 375/375	 Error: 0.622	 Accuracy: 0.78
#
#
# 	 Epoch: 36
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 495.6
#
#
# Epoch: 37/50	 Batch: 25/375	 Error: 0.375	 Accuracy: 0.78
# Epoch: 37/50	 Batch: 50/375	 Error: 0.482	 Accuracy: 0.84
# Epoch: 37/50	 Batch: 75/375	 Error: 0.352	 Accuracy: 0.91
# Epoch: 37/50	 Batch: 100/375	 Error: 0.243	 Accuracy: 0.97
# Epoch: 37/50	 Batch: 125/375	 Error: 0.558	 Accuracy: 0.78
# Epoch: 37/50	 Batch: 150/375	 Error: 0.424	 Accuracy: 0.81
# Epoch: 37/50	 Batch: 175/375	 Error: 0.502	 Accuracy: 0.81
# Epoch: 37/50	 Batch: 200/375	 Error: 0.313	 Accuracy: 0.91
# Epoch: 37/50	 Batch: 225/375	 Error: 0.500	 Accuracy: 0.75
# Epoch: 37/50	 Batch: 250/375	 Error: 0.454	 Accuracy: 0.81
# Epoch: 37/50	 Batch: 275/375	 Error: 0.440	 Accuracy: 0.81
# Epoch: 37/50	 Batch: 300/375	 Error: 0.372	 Accuracy: 0.91
# Epoch: 37/50	 Batch: 325/375	 Error: 0.301	 Accuracy: 0.91
# Epoch: 37/50	 Batch: 350/375	 Error: 0.233	 Accuracy: 0.91
# Epoch: 37/50	 Batch: 375/375	 Error: 0.252	 Accuracy: 0.93
#
#
# 	 Epoch: 37
# 	 Validation loss: 0.38
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 508.4
#
#
# Epoch: 38/50	 Batch: 25/375	 Error: 0.402	 Accuracy: 0.84
# Epoch: 38/50	 Batch: 50/375	 Error: 0.464	 Accuracy: 0.81
# Epoch: 38/50	 Batch: 75/375	 Error: 0.439	 Accuracy: 0.91
# Epoch: 38/50	 Batch: 100/375	 Error: 0.325	 Accuracy: 0.91
# Epoch: 38/50	 Batch: 125/375	 Error: 0.205	 Accuracy: 0.94
# Epoch: 38/50	 Batch: 150/375	 Error: 0.390	 Accuracy: 0.84
# Epoch: 38/50	 Batch: 175/375	 Error: 0.329	 Accuracy: 0.84
# Epoch: 38/50	 Batch: 200/375	 Error: 0.207	 Accuracy: 0.97
# Epoch: 38/50	 Batch: 225/375	 Error: 0.369	 Accuracy: 0.91
# Epoch: 38/50	 Batch: 250/375	 Error: 0.283	 Accuracy: 0.94
# Epoch: 38/50	 Batch: 275/375	 Error: 0.297	 Accuracy: 0.91
# Epoch: 38/50	 Batch: 300/375	 Error: 0.314	 Accuracy: 0.91
# Epoch: 38/50	 Batch: 325/375	 Error: 0.299	 Accuracy: 0.91
# Epoch: 38/50	 Batch: 350/375	 Error: 0.439	 Accuracy: 0.84
# Epoch: 38/50	 Batch: 375/375	 Error: 0.718	 Accuracy: 0.78
#
#
# 	 Epoch: 38
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 521.3
#
#
# Epoch: 39/50	 Batch: 25/375	 Error: 0.377	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 50/375	 Error: 0.542	 Accuracy: 0.91
# Epoch: 39/50	 Batch: 75/375	 Error: 0.307	 Accuracy: 0.84
# Epoch: 39/50	 Batch: 100/375	 Error: 0.646	 Accuracy: 0.72
# Epoch: 39/50	 Batch: 125/375	 Error: 0.309	 Accuracy: 0.91
# Epoch: 39/50	 Batch: 150/375	 Error: 0.408	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 175/375	 Error: 0.454	 Accuracy: 0.81
# Epoch: 39/50	 Batch: 200/375	 Error: 0.394	 Accuracy: 0.84
# Epoch: 39/50	 Batch: 225/375	 Error: 0.284	 Accuracy: 0.94
# Epoch: 39/50	 Batch: 250/375	 Error: 0.179	 Accuracy: 0.97
# Epoch: 39/50	 Batch: 275/375	 Error: 0.331	 Accuracy: 0.84
# Epoch: 39/50	 Batch: 300/375	 Error: 0.256	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 325/375	 Error: 0.432	 Accuracy: 0.88
# Epoch: 39/50	 Batch: 350/375	 Error: 0.128	 Accuracy: 0.94
# Epoch: 39/50	 Batch: 375/375	 Error: 0.142	 Accuracy: 1.00
#
#
# 	 Epoch: 39
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 534.0
#
#
# Epoch: 40/50	 Batch: 25/375	 Error: 0.411	 Accuracy: 0.84
# Epoch: 40/50	 Batch: 50/375	 Error: 0.447	 Accuracy: 0.88
# Epoch: 40/50	 Batch: 75/375	 Error: 0.459	 Accuracy: 0.81
# Epoch: 40/50	 Batch: 100/375	 Error: 0.195	 Accuracy: 0.94
# Epoch: 40/50	 Batch: 125/375	 Error: 0.263	 Accuracy: 0.84
# Epoch: 40/50	 Batch: 150/375	 Error: 0.132	 Accuracy: 0.94
# Epoch: 40/50	 Batch: 175/375	 Error: 0.449	 Accuracy: 0.88
# Epoch: 40/50	 Batch: 200/375	 Error: 0.364	 Accuracy: 0.94
# Epoch: 40/50	 Batch: 225/375	 Error: 0.329	 Accuracy: 0.84
# Epoch: 40/50	 Batch: 250/375	 Error: 0.439	 Accuracy: 0.88
# Epoch: 40/50	 Batch: 275/375	 Error: 0.466	 Accuracy: 0.88
# Epoch: 40/50	 Batch: 300/375	 Error: 0.452	 Accuracy: 0.88
# Epoch: 40/50	 Batch: 325/375	 Error: 0.335	 Accuracy: 0.84
# Epoch: 40/50	 Batch: 350/375	 Error: 0.463	 Accuracy: 0.84
# Epoch: 40/50	 Batch: 375/375	 Error: 0.310	 Accuracy: 0.89
#
#
# 	 Epoch: 40
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 546.6
#
#
# Epoch: 41/50	 Batch: 25/375	 Error: 0.271	 Accuracy: 0.88
# Epoch: 41/50	 Batch: 50/375	 Error: 0.438	 Accuracy: 0.88
# Epoch: 41/50	 Batch: 75/375	 Error: 0.336	 Accuracy: 0.91
# Epoch: 41/50	 Batch: 100/375	 Error: 0.432	 Accuracy: 0.91
# Epoch: 41/50	 Batch: 125/375	 Error: 0.621	 Accuracy: 0.81
# Epoch: 41/50	 Batch: 150/375	 Error: 0.528	 Accuracy: 0.81
# Epoch: 41/50	 Batch: 175/375	 Error: 0.649	 Accuracy: 0.84
# Epoch: 41/50	 Batch: 200/375	 Error: 0.174	 Accuracy: 0.94
# Epoch: 41/50	 Batch: 225/375	 Error: 0.399	 Accuracy: 0.81
# Epoch: 41/50	 Batch: 250/375	 Error: 0.326	 Accuracy: 0.84
# Epoch: 41/50	 Batch: 275/375	 Error: 0.185	 Accuracy: 0.94
# Epoch: 41/50	 Batch: 300/375	 Error: 0.349	 Accuracy: 0.91
# Epoch: 41/50	 Batch: 325/375	 Error: 0.211	 Accuracy: 0.91
# Epoch: 41/50	 Batch: 350/375	 Error: 0.377	 Accuracy: 0.81
# Epoch: 41/50	 Batch: 375/375	 Error: 0.253	 Accuracy: 0.93
#
#
# 	 Epoch: 41
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 559.2
#
#
# Epoch: 42/50	 Batch: 25/375	 Error: 0.545	 Accuracy: 0.81
# Epoch: 42/50	 Batch: 50/375	 Error: 0.626	 Accuracy: 0.78
# Epoch: 42/50	 Batch: 75/375	 Error: 0.551	 Accuracy: 0.78
# Epoch: 42/50	 Batch: 100/375	 Error: 0.357	 Accuracy: 0.88
# Epoch: 42/50	 Batch: 125/375	 Error: 0.211	 Accuracy: 0.88
# Epoch: 42/50	 Batch: 150/375	 Error: 0.505	 Accuracy: 0.84
# Epoch: 42/50	 Batch: 175/375	 Error: 0.245	 Accuracy: 0.88
# Epoch: 42/50	 Batch: 200/375	 Error: 0.105	 Accuracy: 0.97
# Epoch: 42/50	 Batch: 225/375	 Error: 0.314	 Accuracy: 0.91
# Epoch: 42/50	 Batch: 250/375	 Error: 0.347	 Accuracy: 0.84
# Epoch: 42/50	 Batch: 275/375	 Error: 0.468	 Accuracy: 0.81
# Epoch: 42/50	 Batch: 300/375	 Error: 0.210	 Accuracy: 0.94
# Epoch: 42/50	 Batch: 325/375	 Error: 0.457	 Accuracy: 0.84
# Epoch: 42/50	 Batch: 350/375	 Error: 0.256	 Accuracy: 0.94
# Epoch: 42/50	 Batch: 375/375	 Error: 0.297	 Accuracy: 0.81
#
#
# 	 Epoch: 42
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 571.9
#
#
# Epoch: 43/50	 Batch: 25/375	 Error: 0.316	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 50/375	 Error: 0.150	 Accuracy: 0.94
# Epoch: 43/50	 Batch: 75/375	 Error: 0.219	 Accuracy: 0.94
# Epoch: 43/50	 Batch: 100/375	 Error: 0.252	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 125/375	 Error: 0.212	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 150/375	 Error: 0.102	 Accuracy: 1.00
# Epoch: 43/50	 Batch: 175/375	 Error: 0.387	 Accuracy: 0.81
# Epoch: 43/50	 Batch: 200/375	 Error: 0.395	 Accuracy: 0.81
# Epoch: 43/50	 Batch: 225/375	 Error: 0.223	 Accuracy: 0.91
# Epoch: 43/50	 Batch: 250/375	 Error: 0.419	 Accuracy: 0.84
# Epoch: 43/50	 Batch: 275/375	 Error: 0.154	 Accuracy: 0.94
# Epoch: 43/50	 Batch: 300/375	 Error: 0.321	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 325/375	 Error: 0.424	 Accuracy: 0.84
# Epoch: 43/50	 Batch: 350/375	 Error: 0.334	 Accuracy: 0.88
# Epoch: 43/50	 Batch: 375/375	 Error: 0.490	 Accuracy: 0.78
#
#
# 	 Epoch: 43
# 	 Validation loss: 0.40
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 584.6
#
#
# Epoch: 44/50	 Batch: 25/375	 Error: 0.695	 Accuracy: 0.72
# Epoch: 44/50	 Batch: 50/375	 Error: 0.340	 Accuracy: 0.88
# Epoch: 44/50	 Batch: 75/375	 Error: 0.333	 Accuracy: 0.88
# Epoch: 44/50	 Batch: 100/375	 Error: 0.350	 Accuracy: 0.81
# Epoch: 44/50	 Batch: 125/375	 Error: 0.273	 Accuracy: 0.88
# Epoch: 44/50	 Batch: 150/375	 Error: 0.181	 Accuracy: 0.97
# Epoch: 44/50	 Batch: 175/375	 Error: 0.464	 Accuracy: 0.84
# Epoch: 44/50	 Batch: 200/375	 Error: 0.478	 Accuracy: 0.81
# Epoch: 44/50	 Batch: 225/375	 Error: 0.190	 Accuracy: 0.94
# Epoch: 44/50	 Batch: 250/375	 Error: 0.277	 Accuracy: 0.94
# Epoch: 44/50	 Batch: 275/375	 Error: 0.318	 Accuracy: 0.88
# Epoch: 44/50	 Batch: 300/375	 Error: 0.453	 Accuracy: 0.75
# Epoch: 44/50	 Batch: 325/375	 Error: 0.311	 Accuracy: 0.91
# Epoch: 44/50	 Batch: 350/375	 Error: 0.280	 Accuracy: 0.91
# Epoch: 44/50	 Batch: 375/375	 Error: 0.406	 Accuracy: 0.81
#
#
# 	 Epoch: 44
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 597.3
#
#
# Epoch: 45/50	 Batch: 25/375	 Error: 0.210	 Accuracy: 0.91
# Epoch: 45/50	 Batch: 50/375	 Error: 0.661	 Accuracy: 0.78
# Epoch: 45/50	 Batch: 75/375	 Error: 0.277	 Accuracy: 0.94
# Epoch: 45/50	 Batch: 100/375	 Error: 0.416	 Accuracy: 0.84
# Epoch: 45/50	 Batch: 125/375	 Error: 0.284	 Accuracy: 0.81
# Epoch: 45/50	 Batch: 150/375	 Error: 0.120	 Accuracy: 0.97
# Epoch: 45/50	 Batch: 175/375	 Error: 0.241	 Accuracy: 0.94
# Epoch: 45/50	 Batch: 200/375	 Error: 0.488	 Accuracy: 0.78
# Epoch: 45/50	 Batch: 225/375	 Error: 0.393	 Accuracy: 0.88
# Epoch: 45/50	 Batch: 250/375	 Error: 0.576	 Accuracy: 0.84
# Epoch: 45/50	 Batch: 275/375	 Error: 0.264	 Accuracy: 0.91
# Epoch: 45/50	 Batch: 300/375	 Error: 0.309	 Accuracy: 0.88
# Epoch: 45/50	 Batch: 325/375	 Error: 0.464	 Accuracy: 0.84
# Epoch: 45/50	 Batch: 350/375	 Error: 0.301	 Accuracy: 0.91
# Epoch: 45/50	 Batch: 375/375	 Error: 0.316	 Accuracy: 0.85
#
#
# 	 Epoch: 45
# 	 Validation loss: 0.38
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 610.0
#
#
# Epoch: 46/50	 Batch: 25/375	 Error: 0.286	 Accuracy: 0.94
# Epoch: 46/50	 Batch: 50/375	 Error: 0.321	 Accuracy: 0.84
# Epoch: 46/50	 Batch: 75/375	 Error: 0.356	 Accuracy: 0.84
# Epoch: 46/50	 Batch: 100/375	 Error: 0.412	 Accuracy: 0.78
# Epoch: 46/50	 Batch: 125/375	 Error: 0.238	 Accuracy: 0.88
# Epoch: 46/50	 Batch: 150/375	 Error: 0.517	 Accuracy: 0.84
# Epoch: 46/50	 Batch: 175/375	 Error: 0.638	 Accuracy: 0.78
# Epoch: 46/50	 Batch: 200/375	 Error: 0.173	 Accuracy: 0.91
# Epoch: 46/50	 Batch: 225/375	 Error: 0.326	 Accuracy: 0.88
# Epoch: 46/50	 Batch: 250/375	 Error: 0.671	 Accuracy: 0.78
# Epoch: 46/50	 Batch: 275/375	 Error: 0.210	 Accuracy: 0.91
# Epoch: 46/50	 Batch: 300/375	 Error: 0.204	 Accuracy: 0.94
# Epoch: 46/50	 Batch: 325/375	 Error: 0.160	 Accuracy: 0.97
# Epoch: 46/50	 Batch: 350/375	 Error: 0.597	 Accuracy: 0.81
# Epoch: 46/50	 Batch: 375/375	 Error: 0.596	 Accuracy: 0.74
#
#
# 	 Epoch: 46
# 	 Validation loss: 0.38
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 622.8
#
#
# Epoch: 47/50	 Batch: 25/375	 Error: 0.302	 Accuracy: 0.91
# Epoch: 47/50	 Batch: 50/375	 Error: 0.502	 Accuracy: 0.84
# Epoch: 47/50	 Batch: 75/375	 Error: 0.244	 Accuracy: 0.91
# Epoch: 47/50	 Batch: 100/375	 Error: 0.319	 Accuracy: 0.81
# Epoch: 47/50	 Batch: 125/375	 Error: 0.235	 Accuracy: 0.88
# Epoch: 47/50	 Batch: 150/375	 Error: 0.133	 Accuracy: 0.94
# Epoch: 47/50	 Batch: 175/375	 Error: 0.236	 Accuracy: 0.91
# Epoch: 47/50	 Batch: 200/375	 Error: 0.344	 Accuracy: 0.88
# Epoch: 47/50	 Batch: 225/375	 Error: 0.141	 Accuracy: 0.97
# Epoch: 47/50	 Batch: 250/375	 Error: 0.196	 Accuracy: 0.91
# Epoch: 47/50	 Batch: 275/375	 Error: 0.271	 Accuracy: 0.91
# Epoch: 47/50	 Batch: 300/375	 Error: 0.161	 Accuracy: 0.94
# Epoch: 47/50	 Batch: 325/375	 Error: 0.277	 Accuracy: 0.91
# Epoch: 47/50	 Batch: 350/375	 Error: 0.505	 Accuracy: 0.66
# Epoch: 47/50	 Batch: 375/375	 Error: 0.420	 Accuracy: 0.81
#
#
# 	 Epoch: 47
# 	 Validation loss: 0.40
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 635.6
#
#
# Epoch: 48/50	 Batch: 25/375	 Error: 0.259	 Accuracy: 0.91
# Epoch: 48/50	 Batch: 50/375	 Error: 0.144	 Accuracy: 1.00
# Epoch: 48/50	 Batch: 75/375	 Error: 0.585	 Accuracy: 0.84
# Epoch: 48/50	 Batch: 100/375	 Error: 0.272	 Accuracy: 0.91
# Epoch: 48/50	 Batch: 125/375	 Error: 0.268	 Accuracy: 0.88
# Epoch: 48/50	 Batch: 150/375	 Error: 0.176	 Accuracy: 0.97
# Epoch: 48/50	 Batch: 175/375	 Error: 0.405	 Accuracy: 0.94
# Epoch: 48/50	 Batch: 200/375	 Error: 0.284	 Accuracy: 0.88
# Epoch: 48/50	 Batch: 225/375	 Error: 0.518	 Accuracy: 0.84
# Epoch: 48/50	 Batch: 250/375	 Error: 0.333	 Accuracy: 0.91
# Epoch: 48/50	 Batch: 275/375	 Error: 0.496	 Accuracy: 0.81
# Epoch: 48/50	 Batch: 300/375	 Error: 0.219	 Accuracy: 0.94
# Epoch: 48/50	 Batch: 325/375	 Error: 0.224	 Accuracy: 0.97
# Epoch: 48/50	 Batch: 350/375	 Error: 0.688	 Accuracy: 0.75
# Epoch: 48/50	 Batch: 375/375	 Error: 0.311	 Accuracy: 0.81
#
#
# 	 Epoch: 48
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 648.6
#
#
# Epoch: 49/50	 Batch: 25/375	 Error: 0.256	 Accuracy: 0.88
# Epoch: 49/50	 Batch: 50/375	 Error: 0.257	 Accuracy: 0.88
# Epoch: 49/50	 Batch: 75/375	 Error: 0.159	 Accuracy: 0.94
# Epoch: 49/50	 Batch: 100/375	 Error: 0.216	 Accuracy: 0.91
# Epoch: 49/50	 Batch: 125/375	 Error: 0.123	 Accuracy: 1.00
# Epoch: 49/50	 Batch: 150/375	 Error: 0.319	 Accuracy: 0.81
# Epoch: 49/50	 Batch: 175/375	 Error: 0.456	 Accuracy: 0.81
# Epoch: 49/50	 Batch: 200/375	 Error: 0.067	 Accuracy: 1.00
# Epoch: 49/50	 Batch: 225/375	 Error: 0.255	 Accuracy: 0.88
# Epoch: 49/50	 Batch: 250/375	 Error: 0.190	 Accuracy: 0.94
# Epoch: 49/50	 Batch: 275/375	 Error: 0.320	 Accuracy: 0.88
# Epoch: 49/50	 Batch: 300/375	 Error: 0.144	 Accuracy: 0.94
# Epoch: 49/50	 Batch: 325/375	 Error: 0.425	 Accuracy: 0.84
# Epoch: 49/50	 Batch: 350/375	 Error: 0.360	 Accuracy: 0.81
# Epoch: 49/50	 Batch: 375/375	 Error: 0.353	 Accuracy: 0.78
#
#
# 	 Epoch: 49
# 	 Validation loss: 0.39
# 	 Validation accuracy: 0.88
# 	 Elapsed time: 661.3
#
#
# Epoch: 50/50	 Batch: 25/375	 Error: 0.411	 Accuracy: 0.88
# Epoch: 50/50	 Batch: 50/375	 Error: 0.154	 Accuracy: 0.94
# Epoch: 50/50	 Batch: 75/375	 Error: 0.308	 Accuracy: 0.91
# Epoch: 50/50	 Batch: 100/375	 Error: 0.336	 Accuracy: 0.88
# Epoch: 50/50	 Batch: 125/375	 Error: 0.535	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 150/375	 Error: 0.234	 Accuracy: 0.88
# Epoch: 50/50	 Batch: 175/375	 Error: 0.325	 Accuracy: 0.88
# Epoch: 50/50	 Batch: 200/375	 Error: 0.192	 Accuracy: 0.97
# Epoch: 50/50	 Batch: 225/375	 Error: 0.147	 Accuracy: 0.94
# Epoch: 50/50	 Batch: 250/375	 Error: 0.301	 Accuracy: 0.88
# Epoch: 50/50	 Batch: 275/375	 Error: 0.327	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 300/375	 Error: 0.630	 Accuracy: 0.78
# Epoch: 50/50	 Batch: 325/375	 Error: 0.733	 Accuracy: 0.78
# Epoch: 50/50	 Batch: 350/375	 Error: 0.241	 Accuracy: 0.84
# Epoch: 50/50	 Batch: 375/375	 Error: 0.161	 Accuracy: 0.96
#
#
# 	 Epoch: 50
# 	 Validation loss: 0.40
# 	 Validation accuracy: 0.87
# 	 Elapsed time: 673.9

# %%
fname = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/eval_preds_{}.p'.format(WHICH_TARGET)
with open(fname, 'wb') as f:
    pickle.dump(eval_preds, f)

# %%
plot_tracks(
    train_track['error'],
    train_track['accuracy'],
    eval_errors = eval_track['error'],
    eval_accuracies = eval_track['accuracy'],
    file_name = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/tracks_{}.png'.format(WHICH_TARGET)
)

# %%
tester = ecnumTester(trainer.model, test_dataset)
err, acc = tester.test()
print('Test accuracy: {:1.2f}'.format(acc))
# Out:
# Test accuracy: 0.87

# %%
report = tester.get_report()
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91       575
#            1       0.90      0.85      0.87      1071
#            2       0.83      0.93      0.88      1064
#            3       0.84      0.70      0.76       278
#            4       0.90      0.74      0.81       169
#            5       0.91      0.84      0.88       146
#            6       0.62      0.55      0.58        29
#
#     accuracy                           0.87      3332
#    macro avg       0.84      0.79      0.81      3332
# weighted avg       0.87      0.87      0.87      3332

# %%
cm = tester.get_confmat()
plot_confmat(
    cm, 
    file_name = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/confmat_{}.png'.format(WHICH_TARGET)
)

# %%
fpr, tpr, auroc = tester.get_roc()
plot_rocs(
    fpr, 
    tpr, 
    auroc, 
    file_name = '/content/drive/Othercomputers/My MacBook Pro/MIE1517_nlp_proteins/results/rocs_{}.png'.format(WHICH_TARGET)
)

# %% [markdown]
# ---
